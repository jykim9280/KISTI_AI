# %% [markdown]
# <a href="https://colab.research.google.com/github/jykim9280/KISTI_AI/blob/jiyeon/BERT_%EC%A7%80%EC%97%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers datasets torch
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.44.2)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (3.0.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.4.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.24.7)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.5)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (16.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets) (2024.6.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.10.9)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.13.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)

# %%
import os
import json
import torch
import torch.nn as nn
from transformers import BertTokenizer, BertForQuestionAnswering, Trainer, TrainingArguments
from datasets import load_dataset

# Google Drive에서 데이터 파일 경로 설정
folder_path = '/content/drive/MyDrive/KISTI_AI/국정감사/16'  # Google Drive의 실제 경로를 사용

# 학습 데이터 저장할 리스트
training_data = []

# 폴더 내 모든 JSON 파일을 불러오기
for filename in os.listdir(folder_path):
    if filename.endswith(".json"):
        file_path = os.path.join(folder_path, filename)

        try:
            # JSON 파일 열기
            with open(file_path, 'r', encoding='utf-8') as f:
                data = json.load(f)

                # 질문과 답변 추출 (데이터 구조에 따라 수정 필요)
                question = data.get('question', {}).get('comment', '')
                answer = data.get('answer', {}).get('comment', '')
                context = data.get('context', '')

                if question and answer:
                    # 학습 데이터 리스트에 추가
                    training_data.append({"question": question, "answer": answer, "context": context})
        except Exception as e:
            print(f"Error loading {filename}: {e}")

# 학습용 텍스트 파일로 저장
with open('training_data.json', 'w', encoding='utf-8') as f:
    json.dump(training_data, f, ensure_ascii=False, indent=4)

# %%
# 데이터셋 로드
dataset = load_dataset('json', data_files={'train': 'training_data.json'})

# Hugging Face BERT 모델 및 토크나이저 불러오기
model_name = "bert-large-uncased-whole-word-masking-finetuned-squad"
tokenizer = BertTokenizer.from_pretrained(model_name)
model = BertForQuestionAnswering.from_pretrained(model_name)
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Some weights of the model checkpoint at bert-large-uncased-whole-word-masking-finetuned-squad were not used when initializing BertForQuestionAnswering: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
# GPU/CPU 설정 (Colab에서는 GPU 사용)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)  # 모델을 GPU로 이동

# 데이터셋 토큰화 (질문, 문맥 및 답변 위치)
def tokenize_function(examples):
    questions = examples['question']
    contexts = examples['context']
    answers = examples['answer']

    inputs = tokenizer(questions, contexts, padding=True, truncation=True, max_length=512, return_tensors="pt").to(device)

    # start_positions와 end_positions 계산
    start_positions = []
    end_positions = []
    for i in range(len(answers)):
        answer = answers[i]
        context = contexts[i]

        # 답변이 문맥에서 어디에 있는지 찾기
        start_idx = context.find(answer)
        if start_idx == -1:
            start_idx = 0  # 답변을 찾지 못하면 0으로 설정
        end_idx = start_idx + len(answer)

        start_positions.append(start_idx)
        end_positions.append(end_idx)

    inputs['start_positions'] = torch.tensor(start_positions).to(device)
    inputs['end_positions'] = torch.tensor(end_positions).to(device)

    return inputs

# 데이터셋에 대해 토큰화 적용
tokenized_datasets = dataset.map(tokenize_function, batched=True)
# Out:
# Map:   0%|          | 0/32 [00:00<?, ? examples/s]
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.

# %%
# 손실 함수 정의 및 Trainer 설정
class CustomTrainer(Trainer):
    def compute_loss(self, model, inputs, return_outputs=False):
        start_positions = inputs.pop("start_positions")
        end_positions = inputs.pop("end_positions")
        outputs = model(**inputs, start_positions=start_positions, end_positions=end_positions)
        loss = outputs.loss
        return (loss, outputs) if return_outputs else loss

# 학습 인자 설정
training_args = TrainingArguments(
    output_dir="./results",
    per_device_train_batch_size=4,         # GPU에서는 더 큰 배치 크기 사용 가능
    gradient_accumulation_steps=4,         # 그래디언트 누적
    num_train_epochs=3,                    # 학습 에포크 수
    logging_dir='./logs',                  # 로그 저장 경로
)

# Trainer 초기화
trainer = CustomTrainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_datasets['train'],
)

# 학습 시작
trainer.train()

# 모델 저장
model.save_pretrained("./fine_tuned_bert")
tokenizer.save_pretrained("./fine_tuned_bert")

# 나중에 모델 불러오기
model = BertForQuestionAnswering.from_pretrained("./fine_tuned_bert")
tokenizer = BertTokenizer.from_pretrained("./fine_tuned_bert")
# Out:
#     <div>
#
#       <progress value='6' max='6' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [6/6 01:24, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>

# %%
# BERT 모델을 이용한 질의응답 처리 함수
def answer_question(question, context):
    inputs = tokenizer.encode_plus(question, context, return_tensors="pt")

    print(f"Question: {question}")
    print(f"Context: {context}")  # 문맥이 제대로 입력되었는지 확인

    with torch.no_grad():
        outputs = model(**inputs)
        answer_start = torch.argmax(outputs.start_logits)
        answer_end = torch.argmax(outputs.end_logits) + 1
        answer = tokenizer.convert_tokens_to_string(tokenizer.convert_ids_to_tokens(inputs["input_ids"][0][answer_start:answer_end]))
    return answer

# %%
import os
import json
import re

# 간단한 키워드 추출 함수 (명사 기반 추출, Mecab 등 사용 가능)
def extract_keywords(text):
    # 간단히 정규식을 사용한 명사 추출 (Mecab 등 전문 도구 사용 권장)
    keywords = re.findall(r'\b\w+\b', text)
    return keywords

# 검증 함수 (키워드 기반으로 문맥 찾기)
def evaluate_model():
    folder_path = '/content/drive/MyDrive/KISTI_AI/국정감사/16'  # JSON 데이터 경로

    while True:
        test_question = input("질문을 입력하세요 (종료하려면 '종료'라고 입력하세요): ")

        if test_question.lower() == "종료":
            print("챗봇을 종료합니다.")
            break

        # 키워드 추출 (Mecab 같은 형태소 분석기를 사용하는 것이 더 정확함)
        question_keywords = extract_keywords(test_question)

        found_context = ""
        for filename in os.listdir(folder_path):
            if filename.endswith(".json"):
                file_path = os.path.join(folder_path, filename)

                with open(file_path, 'r', encoding='utf-8') as f:
                    data = json.load(f)
                    context = data.get('context', '')
                    question = data.get('question', {}).get('comment', '')

                    # JSON 파일의 질문에서도 키워드를 추출
                    question_in_file_keywords = extract_keywords(question)

                    # 키워드가 겹치는지 확인 (키워드가 겹치면 문맥을 찾은 것으로 간주)
                    if any(keyword in question_in_file_keywords for keyword in question_keywords):
                        found_context = context
                        break

        if not found_context:
            print("문맥을 찾지 못했습니다. 데이터에서 관련 문맥을 찾을 수 없습니다.")
            continue

        print(f"\n[질문]: {test_question}")
        print(f"[문맥]: {found_context}")

        # 문맥을 모델에 전달하여 답변 생성
        response = answer_question(test_question, found_context)

        print("\n[대답]:", response)
        print("\n")

if __name__ == "__main__":
    evaluate_model()
# Out:
# 질문을 입력하세요 (종료하려면 '종료'라고 입력하세요): 건설교통부 산하 12개 기관의 부채가 얼마야?
# 문맥을 찾지 못했습니다. 데이터에서 관련 문맥을 찾을 수 없습니다.
# 질문을 입력하세요 (종료하려면 '종료'라고 입력하세요): 건설교통부 산하 12개 기관의 부채
# 문맥을 찾지 못했습니다. 데이터에서 관련 문맥을 찾을 수 없습니다.
# 질문을 입력하세요 (종료하려면 '종료'라고 입력하세요): SOFA
#
# [질문]: SOFA
# [문맥]: 그 답변 이전에 SOFA 관련해서 제가 물어 보았던 문제의 핵심은 미국 쪽에서도 물론 환경문제를 무시하는 것 같지는 않습니다.  그런데 환경문제를 SOFA의 본문에 별도의 환경조항으로 신설하려고 하지 않고 양해각서나 아니면 부속문서 그런 식으로 하는 것이 아닌가?  그런 여러 가지 관련된 이야기가 나오고 있기 때문에 제가 그 질의를 했는데 장관께서 그 부분에 대해서 명확하게 답변을 안 하시고 넘어가시는 것 같은데 미국 쪽의 입장이 어떻습니까?  환경을 SOFA 본문조항에 포함시키는 대신에 양해각서나 다른 부속문서를 통해 가지고 실질적인 환경보호 그런 부분들로 대체하자는 것 아닌가요? 이와 관련해서는 최근에 미국과 일본 사이에 별도의 문서로서 이 문제를 규율하고 있다.  여러 위원님들이 그것을 염두에 두고 여러 가지 말씀을 하신 것으로 제가 이해를 합니다.   문제는 SOFA 협정에 어떤 내용의 환경조항이 들어가느냐, 그 내용의 문제가 되겠습니다.  그래서 그것은 저희들도 그동안에 저희의 입장을 충분히 개진했고 미측에서도 방금 金 위원님 말씀하신 대로 저희 입장을 충분히 이해하고 있기 때문에 이번 11월 회의에서 초안 제시할 때 그때 아마 구체적으로 파악이 되지 않을까 생각됩니다.  조금만 기다려 주시고 11월의 협상결과는 별도로 저희들이 보고를 드리겠습니다. 이 점에 대해서 제가 한 가지만 여쭙겠습니다.   지금 SOFA의 틀 내에서 환경문제를 다루는 것을 정부에서 골자로 하고 있습니까, 그렇지 않으면 한국 환경법에 주한미군의 여러 가지 환경문제가 적용되도록 하는 것을 골자로 해서 추진하고 있습니까? 전자라고 말씀드리겠습니다. 알겠습니다. 그런데 SOFA의 틀에서 다룬다는 것이 애매하고 지금 장관께서 말씀하시는 것을 보면 물론 협상 중이니까 그 구체적인 내용을 미리 밝히지 못하는 그런 입장은 제가 충분히 이해합니다.  그런데 장관께서 지금 말씀하시는 것을 보면 본질적인 부분이 들어가도록 한다고 말씀하시는데 이 본질적인 부분이 들어간다는 것은 어떤 뜻이지요?  그냥 SOFA 본문에 환경관련된 그런 원칙적인 입장을 표명하고 나머지 구체적인 사안은 다른 문서를 통해서 하겠다 그런 뜻으로 제가 보기에는 판단되는데요. 지금도 SOFA에 환경분과위원회라는 것이 설치가 되어 있습니다.  그래서 협정상에 근거는 없지만 이 환경문제가 되면 이 합동위원회에서 우리가 토의하게 됩니다.  그러나 이 합동위원회에서 협의를 한다는 것은 SOFA의 어떤 규정에 근거한 것은 아니라는 말씀이지요.  그래서 이번에는 어떤 형태로 시행을 하든지간에 본질적인 사항은 협정에 포함시켜야 되지 않겠나 이렇게 생각하고 있습니다. 예, 알았습니다.
# Question: SOFA
# Context: 그 답변 이전에 SOFA 관련해서 제가 물어 보았던 문제의 핵심은 미국 쪽에서도 물론 환경문제를 무시하는 것 같지는 않습니다.  그런데 환경문제를 SOFA의 본문에 별도의 환경조항으로 신설하려고 하지 않고 양해각서나 아니면 부속문서 그런 식으로 하는 것이 아닌가?  그런 여러 가지 관련된 이야기가 나오고 있기 때문에 제가 그 질의를 했는데 장관께서 그 부분에 대해서 명확하게 답변을 안 하시고 넘어가시는 것 같은데 미국 쪽의 입장이 어떻습니까?  환경을 SOFA 본문조항에 포함시키는 대신에 양해각서나 다른 부속문서를 통해 가지고 실질적인 환경보호 그런 부분들로 대체하자는 것 아닌가요? 이와 관련해서는 최근에 미국과 일본 사이에 별도의 문서로서 이 문제를 규율하고 있다.  여러 위원님들이 그것을 염두에 두고 여러 가지 말씀을 하신 것으로 제가 이해를 합니다.   문제는 SOFA 협정에 어떤 내용의 환경조항이 들어가느냐, 그 내용의 문제가 되겠습니다.  그래서 그것은 저희들도 그동안에 저희의 입장을 충분히 개진했고 미측에서도 방금 金 위원님 말씀하신 대로 저희 입장을 충분히 이해하고 있기 때문에 이번 11월 회의에서 초안 제시할 때 그때 아마 구체적으로 파악이 되지 않을까 생각됩니다.  조금만 기다려 주시고 11월의 협상결과는 별도로 저희들이 보고를 드리겠습니다. 이 점에 대해서 제가 한 가지만 여쭙겠습니다.   지금 SOFA의 틀 내에서 환경문제를 다루는 것을 정부에서 골자로 하고 있습니까, 그렇지 않으면 한국 환경법에 주한미군의 여러 가지 환경문제가 적용되도록 하는 것을 골자로 해서 추진하고 있습니까? 전자라고 말씀드리겠습니다. 알겠습니다. 그런데 SOFA의 틀에서 다룬다는 것이 애매하고 지금 장관께서 말씀하시는 것을 보면 물론 협상 중이니까 그 구체적인 내용을 미리 밝히지 못하는 그런 입장은 제가 충분히 이해합니다.  그런데 장관께서 지금 말씀하시는 것을 보면 본질적인 부분이 들어가도록 한다고 말씀하시는데 이 본질적인 부분이 들어간다는 것은 어떤 뜻이지요?  그냥 SOFA 본문에 환경관련된 그런 원칙적인 입장을 표명하고 나머지 구체적인 사안은 다른 문서를 통해서 하겠다 그런 뜻으로 제가 보기에는 판단되는데요. 지금도 SOFA에 환경분과위원회라는 것이 설치가 되어 있습니다.  그래서 협정상에 근거는 없지만 이 환경문제가 되면 이 합동위원회에서 우리가 토의하게 됩니다.  그러나 이 합동위원회에서 협의를 한다는 것은 SOFA의 어떤 규정에 근거한 것은 아니라는 말씀이지요.  그래서 이번에는 어떤 형태로 시행을 하든지간에 본질적인 사항은 협정에 포함시켜야 되지 않겠나 이렇게 생각하고 있습니다. 예, 알았습니다.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-32-73490df4f3ea> in <cell line: 56>()
#      55
#      56 if __name__ == "__main__":
# ---> 57     evaluate_model()
#
# <ipython-input-32-73490df4f3ea> in evaluate_model()
#      49
#      50         # 문맥을 모델에 전달하여 답변 생성
# ---> 51         response = answer_question(test_question, found_context)
#      52
#      53         print("\n[대답]:", response)
#
# <ipython-input-31-e0dddc104b39> in answer_question(question, context)
#       7
#       8     with torch.no_grad():
# ----> 9         outputs = model(**inputs)
#      10         answer_start = torch.argmax(outputs.start_logits)
#      11         answer_end = torch.argmax(outputs.end_logits) + 1
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1551             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552         else:
# -> 1553             return self._call_impl(*args, **kwargs)
#    1554
#    1555     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1560                 or _global_backward_pre_hooks or _global_backward_hooks
#    1561                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562             return forward_call(*args, **kwargs)
#    1563
#    1564         try:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/bert/modeling_bert.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, start_positions, end_positions, output_attentions, output_hidden_states, return_dict)
#    1975         return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#    1976
# -> 1977         outputs = self.bert(
#    1978             input_ids,
#    1979             attention_mask=attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1551             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552         else:
# -> 1553             return self._call_impl(*args, **kwargs)
#    1554
#    1555     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1560                 or _global_backward_pre_hooks or _global_backward_hooks
#    1561                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562             return forward_call(*args, **kwargs)
#    1563
#    1564         try:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/bert/modeling_bert.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#    1075                 token_type_ids = torch.zeros(input_shape, dtype=torch.long, device=device)
#    1076
# -> 1077         embedding_output = self.embeddings(
#    1078             input_ids=input_ids,
#    1079             position_ids=position_ids,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1551             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552         else:
# -> 1553             return self._call_impl(*args, **kwargs)
#    1554
#    1555     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1560                 or _global_backward_pre_hooks or _global_backward_hooks
#    1561                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562             return forward_call(*args, **kwargs)
#    1563
#    1564         try:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/bert/modeling_bert.py in forward(self, input_ids, token_type_ids, position_ids, inputs_embeds, past_key_values_length)
#     214         if self.position_embedding_type == "absolute":
#     215             position_embeddings = self.position_embeddings(position_ids)
# --> 216             embeddings += position_embeddings
#     217         embeddings = self.LayerNorm(embeddings)
#     218         embeddings = self.dropout(embeddings)
#
# RuntimeError: The size of tensor a (1674) must match the size of tensor b (512) at non-singleton dimension 1

# %%
# # JSON 파일에서 question, answer, context를 정확히 추출했는지 확인
# for filename in os.listdir(folder_path):
#     if filename.endswith(".json"):
#         file_path = os.path.join(folder_path, filename)

#         try:
#             with open(file_path, 'r', encoding='utf-8') as f:
#                 data = json.load(f)

#                 question = data.get('question', {}).get('comment', '')
#                 answer = data.get('answer', {}).get('comment', '')
#                 context = data.get('context', '')  # 문맥을 정확히 추출

#                 print(f"Question: {question}")
#                 print(f"Context: {context}")
#                 print(f"Answer: {answer}")

#         except Exception as e:
#             print(f"Error loading {filename}: {e}")
# Out:
# Question: 정품이 단종이 되었을 경우에는 대체품을 쓸 수밖에 없지 않습니까?  그런데 그 제품의 물리적인 특성과 또 설치된 계통의 기능이 일치하는지 또 정품을 쓰지 않았을 때 문제점은 없는지에 대해서 말씀해 주십시오.
# Context: 수고 많으십니다.    9월 4일이니까 지금부터 열흘 전에 옆에 계시는 金榮春 위원이 주관되어가지고 월성원전부지 안전문제에 대해서 국회에서 공개토론회를 했습니다.  알고 계십니까? 알고 있습니다. 신문에도 보도가 되었는데 그날 학계 전문가들 학자들, 환경전문가들도 많이 와서 아주 의미깊은 토론회를 하루종일 했는데 그 내용을 보신 적이 있습니까? 예, 본사를 통해서 받아보았습니다. 그래서 저는 월성원전 부지문제에 대해서 너무 지나치게 위험성이 있는 것처럼 과대포장해서 국민을 불안하게 해서도 안 된다고 생각하고 있고 또 그러나 많은 전문가들이 어쨌든 역사적으로 지진이 많이 일어나고 만에 하나라도 원전에 무슨 사고가 있다면 그것은 이 지역 뿐만 아니라 이 나라, 심지어 세계적인 재앙이 될 수 있기 때문에 절대 가볍게 봐서는 안 된다고 봅니다.  그래서 그 문제에 대해서 지금 신월성 1, 2호기를 건설중인데 그것을 바로 건설해야 된다 아니면 나중에 결과를 보고 해야 된다 하는 여러 가지 의견들이 많은데 그에 대한 의견을 말씀해 주시기 바랍니다.  그 토론회를 보고 느낀 점 또 그에 대해서 그렇기 때문에 어떻게 했으면 좋겠다는 인식을 간단히 말씀해 주세요. 우선 제가 지질 내지 지진전문가가 아니라는 점을 우선 말씀을 드리겠습니다.  그래서 위원님 질의의 핵심에 벗어나는 답변이 될지 걱정됩니다마는 金 위원님이 주관하셔서 개최한 회의기록을 봤습니다.  상당히 의견을 달리하는 학자분들을 모셔다 놓고 하셨는데 저는 깜짝 놀랐습니다.  이렇게 의정활동을 하시는데 참고를 하시려고 이런 활동을 하는 것에 대해서 놀랐고 저는 기술적으로 전문가는 아닙니다마는 양쪽 의견 외에도 또 중재의견이라면 어패가 있겠습니다마는 상당히 균형잡힌 논쟁이 계속 진행되었던 것으로 알고 있습니다. 잘 검토해 보세요.    다음 여러 위원님들이 말씀하시는데 월성원전 배관 감육문제에 대해서 간단히 묻겠습니다.    지금 월성원전은 캔두형인데 우리나라에서 지금 경수형 원전의 경우는 탄소강 배관에 대해서 집중적인 감육검사를 하고 있지요?  그런데 캔두형은 캐나다형이라고 해서 캐나다 규정에 따라서 한다고 해서 지금 5개소에 대한 감육검사만을 하고 있습니까? 그렇지는 않습니다. 캐나다 규정대로만 하면 되는 것입니까?  그것은 아니지요? 그것은 아닙니다. 그러면 제 생각에는 월성원전도 격납건물 관통부의 주증기배관이라든지 또는 주급수 배관을 포함해서 배관 감육검사대상을 좀더 대폭 확대해야 된다고 생각하는데 어떻습니까? 위원님이 저희 회사에서 나간 어떤 자료를 보시고 상황을 그렇게 판단하시는 지는 모르겠습니다마는 저희는 위원님이 지적하신 격납용 기관통배관, 주증기배관, 주급수배관의 감육현상을 측정을 해오고 있습니다. 다행입니다.  그런데 제가 듣기로는 캐나다 캔두형이기 때문에 경수로형 기준과는 달리 캐나다 기준대로만 한다 하는 이야기가 있던데 그것이 아니면 다행입니다.  그다음에 캔두형인 월성원전의 경우 운전 연한이 증가함에 따라서 고열로 인한 파손 및 누설사고 우려가 있다 그래서 당연히 고열에 취약한 배관에 대해서 경수로형 원전과 같이 안전검사를 수행해야 된다고 보는데 이것도 다같이 그렇게 하고 있는 것이지요? 저희가 캐나다 기준만 가지고 하는 것이 아니고요.  과학기술부하고 원자력안전기술원에서 캐나다 기준만 가지고 하는 것은 허용하지를 않습니다. 알았습니다.    그다음에 안전성에 중요한 제어설비문제에 대해서 이야기를 하겠습니다.   월성원전에서 가장 오래된 1호기의 경우에 제어설비가 노후화 되어서 새로 대체해야 되어서 대체해야 하는 부품이 증대되고 있는데 부품업체의 생산 중단 등으로 부품을 공급받는데 많은 어려움이 있는 것으로 알고 있습니다.  현재 생산 중단된 설비부품들은 어떤 것이 있습니까? 꽤 여러 가지가 있습니다.  주로 제어설비용 부품인데요. 그러면 그것 교체할 때는 어떻게 공급받습니까? 한 두 가지로 요약을 해서 말씀드리자면 공급업체가 더 이상 부품생산을 중단하기 직전에 수요자들한테 연락을 합니다.  자기네가 언제부터 이 모델을 생산하지 않을 계획이니까 필요한 고객은 미리 주문을 하십시오 하고 저희들한테 연락이 오는 경우도 있고 그런 저런 연락도 없이 슬그머니 업체 자체가 없어지는 경우도 있습니다.  그런 경우는 저희가 기본설계에 부합하는 대체품을 찾고 있습니다. 정품이 단종이 되었을 경우에는 대체품을 쓸 수밖에 없지 않습니까?  그런데 그 제품의 물리적인 특성과 또 설치된 계통의 기능이 일치하는지 또 정품을 쓰지 않았을 때 문제점은 없는지에 대해서 말씀해 주십시오. 그 문제는 위원님이 염려하시듯이 저희들도 염려를 하고 있습니다.  규제기관도 염려를 하고 있습니다.  정품이 아닌 물건을 써가지고 생길 수 있는 문제 때문에 저희도 상당히 신경을 쓰고 있고 그다음 정품이 아닌 다른 대체품으로 교체할 때 원래 설계개념에 맞는지, 문제가 없는가를 철저하게 저희나 규제기관 입장에서 아주 엄격하게 관련자료를 요구하고 있습니다. 그런데 그것을 철저히 한다고 했는데 새롭게 교체하는 설비의 심사평가를 어떤 과정을 거쳐서 결정을 하는지요.  그런 것을 심사평가하는 과정이 있습니까? 예, 행정적으로 체계가 있습니다.  저희가 교체하고자 합니다 하는 신청서와 함께 기술적인 타당성이 들어 있는 보고서를 제출하면 규제기관에서 그것을 접수해서 검토를 해보시고 무엇인가 미흡한 점이 있으면 저희한테 시정을 요구하거나 경우에 따라서는 실제 규제기관에서 와서 실제테스트 하는 것도 직접 확인하고 그런 일련의 행정절차가 있습니다. 알겠습니다.  잘 해주세요.  그리고 지금 미국에서 큰 사태가 났는데 예를 들면 미국의 상징건물이 무역센터라고 한다면 우리나라의 상징건물이라고 하면 원전 이런 것이 타깃이 될 수도 있습니다.  원전이야 늘 경비를 철저히 하지만 그래도 새로운 인식을 가지고 경비문제 또 안전문제 이런 데 최대한 노력해 주시기를 그래서 국민이 불안해 하지 않도록 해주시기를 간곡히 말씀드리면서 간단히 질의를 마치겠습니다.    수고 많습니다.
# Answer: 그 문제는 위원님이 염려하시듯이 저희들도 염려를 하고 있습니다.  규제기관도 염려를 하고 있습니다.  정품이 아닌 물건을 써가지고 생길 수 있는 문제 때문에 저희도 상당히 신경을 쓰고 있고 그다음 정품이 아닌 다른 대체품으로 교체할 때 원래 설계개념에 맞는지, 문제가 없는가를 철저하게 저희나 규제기관 입장에서 아주 엄격하게 관련자료를 요구하고 있습니다.
# Question: 孫泰仁 위원입니다.   앞에서 선배ㆍ동료 위원들이 많은 지적을 하셔 가지고 사실 이제 지적할 것이 없습니다. 오직 지적할 것이 있다면 수협자체의 존폐문제를 따지는 수밖에 없다 이런 결론에 도달했습니다. 공적자금을 투입하는 것을 계기로 해 가지고 수협중앙회는 독립사업부제로 나누어졌습니다. 그런데 독립사업부제로 나누어진 연유는 잘 알겠습니다마는 독립사업부제로 나누어지고 난 이후에 지도사업이나 경제사업이 제대로 안 됩니다. 특히 수입사업이 아닌 본 사업인 지도가 전혀 제대로 움직일 수 없는 형편에 놓여 있습니다. 그러면 수협이 무엇 때문에 필요합니까? 경제사업은 하는 것마다 전부 적자입니다. 앞에서 위원들이 자세한 자료를 가지고 지적을 다 했습니다. 지금 외발산동이라든지 둔촌백화점은 4층까지 비어 있는데 왜 처리를 안 합니까? 그 이유가 있습니까?
# Context: 孫泰仁 위원입니다.   앞에서 선배ㆍ동료 위원들이 많은 지적을 하셔 가지고 사실 이제 지적할 것이 없습니다. 오직 지적할 것이 있다면 수협자체의 존폐문제를 따지는 수밖에 없다 이런 결론에 도달했습니다. 공적자금을 투입하는 것을 계기로 해 가지고 수협중앙회는 독립사업부제로 나누어졌습니다. 그런데 독립사업부제로 나누어진 연유는 잘 알겠습니다마는 독립사업부제로 나누어지고 난 이후에 지도사업이나 경제사업이 제대로 안 됩니다. 특히 수입사업이 아닌 본 사업인 지도가 전혀 제대로 움직일 수 없는 형편에 놓여 있습니다. 그러면 수협이 무엇 때문에 필요합니까? 경제사업은 하는 것마다 전부 적자입니다. 앞에서 위원들이 자세한 자료를 가지고 지적을 다 했습니다. 지금 외발산동이라든지 둔촌백화점은 4층까지 비어 있는데 왜 처리를 안 합니까? 그 이유가 있습니까? 거기에 지금 현재 200억 들어가 있는데 매물로 내놓은 지가 벌써 2년 되었는데 팔리지 않습니다. 최근까지 저희가 송파구청과 협의를 했는데 실패했습니다. 결과는 안 나왔습니다마는 노력은 하고 있습니다. 그런데 거기에 금융비용이 얼마나 들어갑니까? 200억이니까 연 7%로 해도 1년에 14억이 들어가게 되겠습니다. 거기다가 감가상각까지 하게 되면……. 제 자료로는 40억으로 나왔어요. 다시 계산을 해 보세요.  그리고 외발산동은 아까 적자가 101억이라고 하데요. 외발산동은 금년에 적자가 40억 정도를 추정하고 있습니다. 작년에는요? 작년에는 50억 좀 넘었습니다. 그러면 더 따질 것이 없잖아요?  그런데 또 하나 물어봅시다.  노량진수산시장 1600억 차입을 한다고 합시다. 그러면 노량진수산시장이 지금 흑자가 얼마입니까? 저희가 노량진시장에서 받은 자료에 의하면 누적잉여금이 한 10억 있고 매년 3억에서 5억 정도의 이익을 내는 것으로 나와 있습니다. 그러니까 흑자가 얼마납니까? 3억에서 5억 정도 흑자가 나는 것으로 나와 있습니다. 그런데 1600억의 금융비용이 얼마입니까? 한 110억 정도 되겠지요. 그러면 수협에서 인수를 하면 흑자가 110억 납니까? 저희가 지금 현재 자료에 의하게 되면 75억 정도가 한냉에서 받아가는 것으로 되어 있습니다. 제가 경제사업을 담당하고 있습니다마는 여러 가지 조치를 취하게 되면 40억 정도는 만회할 수 있지 않느냐 하는 생각을 하고서 저희가 이것을 어프로치하고 있는 것입니다. 그 구체적인 자료를 하나 주십시오. 그것이 흑자가 나겠어요? 그래서 아까 여러 위원님들이 그것이 가능할 것이냐고 걱정을 해주셨는데 제가 실무책임자로서는 가능하다고 판단을 해서 책임하에 추진하게 되었습니다. 바다마트는 적자가 나지요? 지금 여러 위원님들께서 바다마트를 말씀하고 계시는데 사실은 맞습니다. 문제점이 있습니다. 그리고 아까 존폐를 검토하라는 말씀도 계셨는데 지금 바다마트는 기본적으로 적자, 흑자 이렇게 됩니다마는 전체적으로 보게 되면 금년에도 한 27억까지 나 있는데 지금 지도관리비 비용을 분담합니다. 사실은 일반 기업의 경상이익 개념으로 치게 되면 금년에 플러스 마이너스 제로로 갑니다. 그리고 위원님들께서 걱정해 주신 것처럼 없앨 것은 없애고 세울 것은 세우고 할 것은 남아 있습니다. 실제로 지금 한 770억 정도가 투입되어 있습니다. 그리고 저희가 17개를 그동안 없앴는데 전부 소규모의 것을 없앴습니다. 그리고 아까 지적했던 것처럼 저희가 시행착오를 해 가지고 지은 지 얼마 안 되는 것도 적자를 내고 있고 또 흑자를 내는 부분도 있습니다. 그런 것을 좀 참조를 해 주십시오. 그러면 신용사업을 자료를 통해서 지적해 보겠습니다.   1조 1600억 원의 공적자금을 투입 받아서 상반기에 신용사업이 105억 원의 흑자를 보는 등 회생의 가능성이 높다고 수협에서는 보고 있지요? 그러나 수협의 상반기 흑자는 공적자금 투입에 따른 일시적인 현상입니다. 근본적으로 수협의 신용사업이 정상적으로 운영되어서 이렇게 나온 것이 아닙니다. 수협은 당장 7%의 이자만 계산해도 연간 810억 원의 특별이익이 발생하고 있습니다. 그런데 겨우 105억 원의 흑자입니다. 성과 운운 하는 것은 너무 성급한 발언입니다.   그다음에 상반기 수협결산의 질적인 내용을 들여다 보더라도 신용사업이 여전히 부실하다는 것이 자료로서 증명이 되고 있습니다. 신용사업 예수금은 2000년 6월 말과 비교해 보면 2.1% 903억 원이 증가한데 불과합니다. 농협을 비교해 보면 올해 들어서 6개월 동안 예수금이 24.1%가 늘어났습니다. 수협은 역시 정체상태에 있다고 볼 수밖에 없습니다. 수협은 신용사업의 본업인 영업이익에서도 47억 원의 적자를 보았을 뿐만 아니라 예대마진이 406억 원에서 374억 원으로 줄었습니다. 기본적으로 영업구조가 아직도 취약하다는 것입니다.   사업의 수익부분에서 투자유가증권 매매이익이 335억 원이나 발생했습니다. 대규모의 적자발생을 줄이고 흑자결산을 했지만 이는 상반기 주식시장의 일시적인 반등 현상으로 볼 수밖에 없습니다. 수협이 신용부분에서 대대적인 구조조정을 한다고 발표를 했지만 인건비 등의 경비가 지난해보다 늘어나서 사업관리비가 오히려 27억 8000만 원이나 증가되었습니다. 신용사업의 사업량은 거의 늘지 않았는데 사업관리비가 늘었다는 것은 아직도 구조조정이 제대로 안 되어 있는 것입니다.  회원조합도 마찬가지입니다. 아까 부실 이야기를 했습니다마는 자본잠식이 작년도까지 45개이고 올해 6월까지 61개입니다. 이러한 자료를 통해서 보면 상반기 흑자결산은 결국 수협의 체질이 개선된 것이 아니라 대규모 공적자금 투입에 따른 일시적인 반사효과외에는 아무 것도 없다 이렇게 봅니다.   아시다시피 현재 금융시장은 급변하고 있습니다. 지주회사라든가 국민 주택은행 합병문제 또는 거대은행이 탄생하고 있고 모든 금융업무를 포괄하는 방향으로 지금 나가고 있습니다.   예수금 4조 원 규모의 초미니은행인 수협이 특화된 분야없이 생존한다는 것은 거의 불가능합니다. 공적자금 효과가 소진되어 버린다면 수협은 자체생존의 가능성이 없다는 결론에 이릅니다. 아마 여기에 관해서도 여러 가지 이의를 제기하실지 모르겠습니다마는 수협은 이 시점에서 신용사업을 해야 될 것인지 말 것인지 정말 고민을 해야 됩니다.   오늘 위원님들이 많은 지적을 했습니다. 지도사업 안돼 경제사업 안돼 신용이 이런데 결국 공적자금 투입에 의한 반사효과에 지나지 않는다 그러면 수협의 존재이유가 무엇입니까?  지금 업무보고에 보면 뉴스타트운동을 벌이고 있습니다. 이런 것이 방향이 제대로 되고 비전이 있는 대책이 나와야 뉴스타트가 되는 것입니다. 그렇지 않습니까? 무엇을 가지고 뉴스타트를 하자는 것입니까?   지금 현황보고도 제대로 된 믿음직한 자료가 아닙니다. 자체 반성이 전혀 없습니다. 이러고서 다른 사업을 하신다고요? 지금 존립이 왔다갔다 하는데 또 노량진수산시장 사서 부동산 투기하자는 것입니까?   지금 해수부에서는 수산물 물류를 위해서 여러 가지 구상이 있는 것으로 알고 있습니다. 여러분도 다 알고 계시지요? 노량진수산시장 대신에 큰 유통구조를 외곽에다 만든다는 것, 도심지에 저런 유통시장이 있을 이유가 없다는 것입니다. 그래서 권역으로 나누겠다는 것 아닙니까? 그것은 이미 용역결과에서 다 나왔습니다. 여러분들이 지금 노리는 것은 수협을 회생시키고 어민들한테 이익을 주자는 것이 아니라 어떻게 보면 땅장사를 해 가지고 일시에 만회를 하는 투기성입니다. 그렇게 안 보십니까? 그런 계산이 깔려 있습니까, 안 깔려 있습니까?  어업신문 이것 누가 발행하는 것입니까? 나는 우연하게 위원장실에 들어가서 신문을 봤는데 그 내용을 읽어보니까 여론몰이를 하고 있어요. 현 회장님이 어디 불도저입니까? 이런 식의 주먹구구 경영 그리고 한나라당이 무엇을 어쨌다는 것입니까? 한나라당이 수협이 노량진수산시장 매입하자는데 반대하는 사람이 있어 가지고 자료를 엄청나게 요청하고 정치적으로 뭉쳤다 이렇게 나와 있어요.   이것 누가 발행하는 신문입니까? 수협하고 관계 있습니까? 직접적인 관계가 없고 저희가 그런 것을 배포한 적이 없습니다. 사장이 누구입니까? 사장이 전에 수협 감사하신 분입니다. ‘노량진수산시장 문제로 해수부 수협 국감 초비상’ 이렇게 ...
# Answer: 거기에 지금 현재 200억 들어가 있는데 매물로 내놓은 지가 벌써 2년 되었는데 팔리지 않습니다. 최근까지 저희가 송파구청과 협의를 했는데 실패했습니다. 결과는 안 나왔습니다마는 노력은 하고 있습니다.
# Question: 차관보, 규제개선을 많이 한다고 하고 500개가 개선됐다고 합니다. 그러나 큰 틀에서 보는 새로운 규제, 바꿔 얘기하면 IMF로 인해서 생긴 규제예요. 경제계가 완화를 요청하는 소위 부채비율…… 잘 아실 거예요. 투자에 대한 엄청난 큰 규제는 산자부의 산업정책과 배치되는 결과가 옵니다. 산업자원을 총괄하고 계시는 장관께서는 재정을 움직이는 쪽하고 엄청난 괴리를 가지고 있는데 거기에 대하여 어떤 의견을 갖고 계신가요?
# Context: 계속 설명 올리겠습니다.   기타 주요 부대조건으로는 채권단에서 20억 달러 한도로 새로운 회사에 Commercial Base로 지원하고 있고 차량판매대금에 대한 9개월간 특소세 징수유예, 외국인 투자지분에 대한 세제감면 등을 지원해 주기로 했습니다.   8페이지가 되겠습니다.   부품협력업체에 대한 대책입니다.   협력업체 동향은 대우차 부도 이후에 30여 개의 주요협력업체가 부도났습니다. 1차 협력업체 24개, 2ㆍ3차 협력업체 6개 해서 30개입니다. 그동안 대우차 생산감소에 따라 부품업체도 납품이 40% 감소되었고 또 대우차를 위해서 일률적인 5% 납품단가 인하 등으로 해서 그동안 부품협력업체들의 자금부담이 가중되어 왔던 것이 사실입니다. 또 협력업제의 정리채권이 그 당시에 1조 4000억 원이었습니다마는 그 중에 40%에 해당하는 5400억 원만 신어음으로 교체지원을 했고 나머지 60%가 현재 잔액으로 남아있는 상황이라서 자금압박이 심각한 상태입니다.  즉 8400억 원이 정리채권 잔액으로 남아있습니다.   9페이지가 되겠습니다.   협력업체의 지원대책으로 미지급 정리채권, 조금 전에 말씀드린 8400억 원의 일부와 11월 법정관리 이후 신규 발생한 소위 공익채권은 GM이 인수한 2.5억 달러, 약 3200억 원 중에서 우선 지급토록 하고 자금부담이 심각한 부품업체에 대해서는 산업은행에서 1223억 원을 융자지원하는 한편 앞으로 더 필요하면 중소기업경영안정자금 등에서 지원해 나갈 방침으로 있습니다. 또 향후 법원에서 정리계획안을 인가할 때 채무조정을 통해서 부품협력업체자금이 우선 변제되도록 유도해 나가겠습니다.   협력업체는 대우자동차가 조기정상화될 경우 장기ㆍ안정적인 납품선의 유지가 가능하게 되고 GM의 글로벌 부품네트워크 참여를 통해 도약할 수 있는 계기를 마련할 수 있을 것으로 기대하고 있습니다.   세 번째, GM매각에 따른 자동차산업 전망과 정책방향입니다.  먼저 자동차산업의 전망입니다.  대우차가 워크아웃 이후 시장점유율 급감으로 현대와 기아의 시장 점유율이 76%로 상당히 강화된 상황입니다. 대우차는 국내시장 점유율이 약 20% 수준에서 11% 수준으로 떨어졌고, 수출도 30%에서 15%로 절반 가까이 줄어들었습니다.  GM 매각으로 인해 소비자 신뢰가 회복될 시에는 대우차의 국내시장 점유율 및 수출이 점차 제고될 것으로 전망하고 있습니다.   10페이지가 되겠습니다.  자동차산업정책 방향은 전략적 제휴와 글로벌 소싱을 통한 선진경영시스템을 구축하고 첨단핵심기술을 확보해서 자동차산업의 질적성장을 추진해 나가겠습니다. 따라서 2010년에는 총 생산 530만 대, 수출 280만 대를 달성하여 세계 3위의 중ㆍ소형차 강국으로 부상한다는 목표를 가지고 있습니다.  대우차의 GM 매각이 단순 하청생산기지가 아닌 아시아의 주요 생산거점이 될 수 있도록 개발, 생산, 품질관리, 판매, A/S 등에서 선진경영기법을 접목할 수 있는 기회로 삼도록 유도하겠습니다.   먼저 국내 자동차산업 인프라 구축지원입니다.  부산대나 전북대 등 7개 지방대학의 자동차분야 지역기술혁신센터(TIC) 사업을 활성화시켜 나가고 자동차부품 기술인력 양성도 적극 추진해 나가겠습니다.   또한 자동차부품의 신뢰성평가센터 운영 등을 통하여 신뢰성을 확보하고 표준화를 지원해 나가는 등 인프라를 적극 구축해 나가겠습니다.   또한 환경ㆍ안전규제에 대응한 기술개발사업도 지속적으로 추진해서 G7 차세대자동차기술개발사업을 2002년까지 마무리하고 하이브리드ㆍ연료전지 자동차 등 미래형자동차 기술개발사업을 내년부터 10년간 정부와 업계 공동으로 총 1조 2500억 원을 투입해서 본격 추진해 나가겠습니다.   또 자동차부품의 수출전략산업화 기반구축을 위해서 세계 부품산업의 대형화 추세와 글로벌에 대비하여 국내부품업계의 전문화ㆍ대형화를 유도하고, 세계일류화상품 추가지정 그리고 미국ㆍ유럽 등 주요지역에 자동차부품 시장개척단 파견과 유수 해외전시회 참가를 적극 지원해 나가겠습니다.   세 번째로 기업규제 실태조사 결과와 조치계획을 말씀올리겠습니다.  먼저 추진배경은 국민의 정부 출범 이후 범정부적인 규제개혁 노력으로 5000여 건의 규제가 철폐되는 등 그동안 많은 성과를 거두었습니다마는 최근 세계경제의 침체와 더불어 우리 기업의 수출과 투자활력이 떨어지고 있어 기업현장의 생생한 애로를 직접 청취하고 이를 범정부 차원에서 해결해 주기 위해 민관 합동 기업규제 실태조사를 추진하였습니다.   공장설립이라든지 공정거래, 수출입, 외국인 투자 등 총 11개 분야에 대해 7월 중순부터 8월 말까지 전국 400여 개 기업을 대상으로 54개 민관 합동 조사팀이 현장 방문조사를 실시했습니다. 그 결과 규제에 해당하는 411건과 관행적인 규제로 볼 수 있는 16건, 또 정책건의 97건 등 총 524건의 각종 규제와 애로사항들을 발굴했습니다.  전반적으로 기업들은 아직도 시급히 개선되어야 할 잔존 규제가 많은 것으로 평가하고 있습니다.   아울러 이에 못지 않게 규제담당 일선 공무원들의 태도나 자세가 시정되지 않고 있는 점을 큰 문제점으로 지적하고 있습니다. 따라서 앞으로 규제의 제도적인 완화와 동시에 완화된 규제가 일선 관서에서 차질없이 실행될 수 있는 보완대책을 마련할 필요가 있다고 보겠습니다.   저희 부는 9월 말 기업규제실태조사 종합보고서와 개선계획을 마련하고 향후 범부처적으로 태스크포스팀을 구성하여 세부 개선계획을 수립ㆍ추진해 나갈 계획입니다. 차관보, 규제개선을 많이 한다고 하고 500개가 개선됐다고 합니다. 그러나 큰 틀에서 보는 새로운 규제, 바꿔 얘기하면 IMF로 인해서 생긴 규제예요. 경제계가 완화를 요청하는 소위 부채비율…… 잘 아실 거예요. 투자에 대한 엄청난 큰 규제는 산자부의 산업정책과 배치되는 결과가 옵니다. 산업자원을 총괄하고 계시는 장관께서는 재정을 움직이는 쪽하고 엄청난 괴리를 가지고 있는데 거기에 대하여 어떤 의견을 갖고 계신가요? 黃勝敏 위원께서 아주 좋은 지적을 해 주셨습니다. 큰 규제가 남아 있는데 이것은 그때그때 여건에 따라 달라지는 것이기 때문에 산자부가 독자적으로 하지 못할 분야입니다.  이번에 우리가 하는 것은 산자부 독자적으로 조사하여…… 물론 관계부처와 협의는 됩니다. 黃 위원님께서 지적하신 것은 경제장관회의에서 그저께도 논의됐고 외부에서 알지 못할 정도로 상당히 심각하게 격론이 벌어지고 있습니다.   그래서 출자제한제도랄지 또 아까 말씀드린 기업에 대한 여러 가지 제약사항 이런 것은 앞으로…… 여기서 명확히 말씀드릴 수 없습니다마는 상당히 완화해 줄 것을 약속 드리겠습니다. 지금 경제장관회의에서도 그런 방향으로 나가고 있습니다. 알겠습니다.
# Answer: 黃勝敏 위원께서 아주 좋은 지적을 해 주셨습니다. 큰 규제가 남아 있는데 이것은 그때그때 여건에 따라 달라지는 것이기 때문에 산자부가 독자적으로 하지 못할 분야입니다.  이번에 우리가 하는 것은 산자부 독자적으로 조사하여…… 물론 관계부처와 협의는 됩니다. 黃 위원님께서 지적하신 것은 경제장관회의에서 그저께도 논의됐고 외부에서 알지 못할 정도로 상당히 심각하게 격론이 벌어지고 있습니다.   그래서 출자제한제도랄지 또 아까 말씀드린 기업에 대한 여러 가지 제약사항 이런 것은 앞으로…… 여기서 명확히 말씀드릴 수 없습니다마는 상당히 완화해 줄 것을 약속 드리겠습니다. 지금 경제장관회의에서도 그런 방향으로 나가고 있습니다.
# Question: 토공의 역할은 극히 한정된 것 아닙니까? 건교부에서 방침을 정해 주어야 되는데…… 보고자료에도 수도권의 임대주택건설 택지난 때문에 개발제한구역 해제대상지역의 개발활용이 불가피하다고 언급되어 있는데 결국 그린벨트 지역 이외에는 수도권에서 개발할 만한 토지의 취득이 어렵다는 얘기이지요?
# Context: 토공의 역할은 극히 한정된 것 아닙니까? 건교부에서 방침을 정해 주어야 되는데…… 보고자료에도 수도권의 임대주택건설 택지난 때문에 개발제한구역 해제대상지역의 개발활용이 불가피하다고 언급되어 있는데 결국 그린벨트 지역 이외에는 수도권에서 개발할 만한 토지의 취득이 어렵다는 얘기이지요? 아닙니다. 오늘 신문에도 일부 발표가 되었습니다마는 개발제한구역 외의 지역도 임대주택 활성화를 위해서 일부 지구지정에 올라가 있습니다. 그런 부분도 있고 또 그린벨트 지역의 임대주택 관계도 토지공사에서 애당초 조사한 내용이 있어서 지금 건교부하고 충분하게 협의를 하고 있습니다.
# Answer: 아닙니다. 오늘 신문에도 일부 발표가 되었습니다마는 개발제한구역 외의 지역도 임대주택 활성화를 위해서 일부 지구지정에 올라가 있습니다. 그런 부분도 있고 또 그린벨트 지역의 임대주택 관계도 토지공사에서 애당초 조사한 내용이 있어서 지금 건교부하고 충분하게 협의를 하고 있습니다.
# Question: 그렇다면 그런 것을 만들기 위해서는 최소한도로 산업재해가 해마다 증가하고 있는 이유 같은 것들은 객관적으로 확보가 되어 있어야 된다고 생각하는데 뭐라고 생각을 하십니까?
# Context: 대단히 반갑습니다. 徐秉洙 위원입니다.   아까 존경하는 朴仁相 위원님께서 중앙노동위원회의 업무와 관련해서 심판사건의 경우에 처리기간이 규정된 기준을 넘어서고 있다는 것을 지적하셨습니다. 그런데 심판사건이 이토록 지연되는 것이 예산의 문제, 인력의 문제가 있다고 지적도 하셨고 답변도 하셨습니다. 그런데 이 문제가 매년 국정감사 때마다 되풀이되고 있지 않습니까? 그 중에서도 심판담당 공익위원의 수를 늘려야 되는 것이 중요하지요? 그렇습니다. 그런데 이것은 법이 바뀌어야 되지 않습니까? 예, 그렇습니다. 그런데 작년 국정감사에서도 노사 공익위원 정원을 확대하자는 의견이 나왔거든요. 기억이 나시지요? 예. 노동부에서 누가 나와 계십니까? 노사정책국장입니다. 당시 노동부의 최병훈 국장이 노사정책국장을 하였지요? 예, 그렇습니다. 그래서 “노사정위원회 노사관계소위에서 노동쟁의 제도와 관련하여 여러 가지 논의가 있는데 거의 마무리 단계에 있으므로 정리가 되는 대로 개정안을 국회에 제출하겠다”고 답변한 바가 있습니다. 국장님, 그 답변 내용을 알고 계십니까? 정확히 알고 있지 못합니다. 나중에 속기록을 한번 찾아보세요.   신홍 위원장님은 기억이 좀 나십니까? 예, 제가 작년에 국감을 받을 때에는 다른 위치에 있었습니다마는 제가 기억하기로는 그 이후에 노사정위원회에서…… 2002년 11월 21일에 노사합의도 된 바가 있지 않습니까? 예, 그때 합의가 되어서 지난 4월에 노동부에서 업무추진계획을 보고할 때 노동위원회법의 개정을 6월에 추진하는 것으로 자료가 나와 있는 것을 제가 보았습니다. 그런데 아직 추진이 안 되고 있지요? 예, 그런데 아까 말씀을 올린 대로 추진이 안 되고 있는 것은 여러 번 이야기가 나온 노사관계제도선진화연구위원회의 연구결과가 노사정위원회에 가 있기 때문에 거기에는…… 그런데 그 내용이 이렇거든요. 노동부가 노사정위원회에 제출한 노사관계법제도선진화방안에도 방금 위원장님이 말씀하신 대로 노동위원회의 기능을 개편ㆍ확대한다는 내용도 포함되어 있습니다.   그러나 노동부의 방안에는 노사정위원회의 작년 11월 합의를 이행하겠다는 의지가 담겨 있는 것으로 보여지지가 않거든요. 왜냐하면 외부의 사례와 함께 노ㆍ사ㆍ정 등 각계 입장 정도로만 격하되어서 지금 보고서가 되어 있다 말입니다.  그리고 또 노동부가 노사정위원회에 어떻게 요구를 했는가 하면 “노, 사, 정, 공익이 심도 있게 논의하여 노동부로 송부하여 주시기를 바람” 이랬거든요. 그런데 이미 작년 11월에 노사정위원회에서 합의가 된 사항인데 그런 것을 다시 노동부가 노사정위원회에다가 심도 있게 의논하라고 한다면 그 뜻이 어디에 있다고 생각하십니까? 제가 이해하기에는 이 문제와 관련된 노사합의 내용이 6월에 제출하기로 되어 있는 노동위원회법 개정안에 포함되어 있는 것으로 알고 있습니다. 그래서 그 내용이 대략 세 가지인데 하나는 지금 10～30명으로 되어 있는 공익위원 숫자를 45명까지 늘릴 수 있도록 하는 것과 심사관의 법적근거를 마련해서 심사관이 법적으로 근거를 가지고 활동할 수 있도록 하는 내용 그다음에 공정성을 제고하기 위해서…… 좋습니다. 그러면 위원장님께서는 이 법안이 제대로 정리되어서 제출이 언제쯤 되리라고 생각을 하십니까? 이미 노동부에서 법안 내용이 확정되었고 노동위원회의 의견도 저희들이 제시를 해서 그 초안이 완성된 것으로 알고 있습니다. 그래서 그 문제와 관련해서는 더 이상 논의의 여지가 없고 지금 위원님께서 말씀하신 노동위원회의 기능과 관련된 여러 가지 문제 또 좋은 방안이 나오면 같이 제출을 하기 위해서 좀 늦어지고 있는 것으로 이해하고 있습니다. 좋습니다. 그러면 한 가지만 더 지적을 하겠습니다.   아까 朴仁相 위원님께서도 지적을 하셨습니다마는 현재 노동위원회법에는 공익위원의 자격과 임기, 신분보장 등은 규정되어 있지만 회의참석 등의 업무 불이행에 따른 제재조치가 마련되어 있지 않습니다. 그렇지요? 예. 그렇기 때문에 심판사건이 누적되는 이유 자체가 공익위원들 모두가 바쁜 분들인 것 같습니다. 그래서 회의 구성이 미루어지고 또 참석률이 저조한 것으로 인해서 문제가 야기되고 있는데 옆에 계시는 김금수 위원장께서도 현재도 중앙노동위원회의 공익위원이시지요? 아닙니다. 그러면 사표를 내셨습니까? 그렇습니다. 그러면 청와대의 이정우 실장은 지금 경북지방노동위원회의 공익위원으로 위촉이 되어 있는 상황이지요? 예, 현재 재직 중에 있습니다. 부산지방노동위원회의 김석준 위원 같은 경우에도 민주노동당 부산시장 후보를 했던 분이거든요. 이분도 아직까지 공익위원으로서 활동을 하고 계시지요? 예, 그렇습니다. 그래서 제가 이 법을 고치실 적에 이러한 점까지도 감안을 해서 일정기간 회의에 참석하지 않는 결격사유가 발생하면 스스로 사표를 내기 이전에라도 어떤 적당한 제재 등을 통해서 다른 사람으로 바꿀 수 있는 제도가 마련되어야 되지 않겠는가라는 점을 지적드립니다. 예, 알겠습니다. 그다음에 산별노조 공동조정신청 사건에 대해서 질의를 하겠습니다.   지금 산별노조 소속 사업장에 대해서 공동조정신청 사건이 대단히 빨리 증가하고 있지요? 그렇습니다. 2001년에 접수된 공동조정신청은 4개 산별노조의 275개 사건이었지만 올해는 7월 현재 벌써 6개 산별노조로부터 488건의 공동조정신청 사건이 접수되었습니다.   그런데 산별노조가 공동으로 조정을 신청한 사건이라고 하더라도 해당 노동위원회의 조정결과가 서로 다르지요? 다를 수밖에 없지 않겠습니까? 다를 수밖에 없습니다. 공동조정신청 사건에서 이렇게 상이한 조정결과가 제시되는 것은 당연한 일이라고 생각을 합니다. 그런데 문제는 그 중에서는 합의된 사업체도 있을 것이고 아닌 사업체도 있지 않겠습니까? 예, 그렇습니다. 그런데 이 합의된 사업체까지 행정지도와 조정중지 등의 결정이 내려진 사업장의 파업에 이른바 연대파업으로 모든 업체들이 동참을 한다는 데에 문제가 있는 것이 아니겠습니까? 모든 업체들이 연대파업을 전제로 해서…… 전제로 한 것은 아니고 결과적으로 그렇다는 이야기예요. 결과적으로 그렇다면 문제가 있습니다. 결과적으로 그렇게 될 수밖에 없었고 지금 그것으로 인해서 사회적인 갈등이 증폭되고 있다고 봅니다. 예, 결과적으로 그렇다면 문제가 있습니다. 그런데 산별노조에 관해서 조정을 한다든가 어떤 대안을 제시할 수 있는 데는 중앙노동위원회밖에는 없지 않습니까? 예, 그런데 지금 위원님께서 우려하신 문제는 저희 중앙노동위원회로서도 뾰족한 대안이 없습니다. 말하자면 준법의식의 문제이기 때문에 저희들로서는…… 그런데 보통 노사분규가 발생한다든가 하면 각 사업장마다 다 목적하는 바가 다르고 이해관계가 다르지 않습니까? 예. 그런데 현 정부 들어와서 산별교섭에 대해서 어느 정도 동의하는 듯한 자세를 보이고 있고 그렇게 지금 교섭이 진행되고 있는 곳도 많이 있지 않습니까? 예. 그렇다면 여기에 대해서 가부간 어떤 결론을 내려주시든지 아니면 산별노조와 협상 쪽을 지향하신다면 여기에서 발생하는 문제가 없도록 어떤 대안을 마련해 놓으셔야 될 것이 아닌가요? 그래서 저희 중노위 입장에서는 산별교섭을 지향한다든지 하는 것은 없습니다. 그러나 지금 경향이 그렇다고 한다면 얼마든지 합법적으로 할 수 있는 것이기 때문에 그런 경우에 연대파업으로 발전하지 않도록 저희가 조정과정에서 성의를 다 해서…… 그런데 여태까지도 조정을 많이 했었습니다만 결과적으로는 그 조정의 노력이 그야말로 아무것도 안 한 것으로밖에 결론이 나지 않았습니까? 다 그런 것은 아니지요. 부분적으로는 합의도 되고 조정도 되고 여러 가지 노력을 많이 하셨습니다마는 결과적으로 그것이 공동파업으로 이어져서…… 공동파업으로 이어진 경우가 많이 있습니다마는 이어지지 않은 산별조정도 많이 있습니다. 위원장님께서 여태까지의 여러 가지 경험과 경륜으로 연구를 제대로 해서 어떤 대응방안을 만들어 내실 생각이 없으십니까? 법리적으로 노동위원회에서 할 수 있는 방안을 연구해 보겠습니다. 예, 한번 찾아서 연구를 해 주십시오.   다음에는 한국산업안전공단이사장님께 질의를 드리겠습니다.   아까 全在姬 위원님께서도 지적을 하셨습니다마는 산업재해가 대단히 급증하고 있습니다. 그래서 2002년, ...
# Answer: 여러 가지 이유가 있겠는데 우선 변명 같습니다마는 1997년도에 우리 산업체가 전반적으로 안 좋아지다 보니까 기업활동규제완화에관한특별조치법에 따라서 안전관리체계나 사업주들의 의식이 많이 약화된 것이 하나의 큰 원인이 될 수 있겠습니다.   그리고 산재예방에 굉장히 취약한 능력을 소유할 수밖에 없는 소규모 사업장이 그동안에 많이 증가를 했고 또 최근에는 근골격계 환자들이 대폭 산재 집단신청을 하다 보니까 작년 7월 동기보다도 107.5%의 근골격계 환자가 집단적으로 늘고 있습니다.
# Question: 제 지역구가 경남 진해인데 경남 진해에서 청소년들이 부탄가스 흡입을 하는 과정에서 담배를 피운다든지 해서 폭발사고로 인해 가지고 화상을 입고 심지어 목숨을 잃은 사례를 제가 여러 번 보았습니다. 제가 이것을 어떻게 알게 되었느냐 하면 이 친구들이 대개 가정적으로 원만하지 못 합니다. 그리고 재정적인 능력이 없다 보니까 사고가 난 뒤에도 의료비를 낼 수가 없어요. 그러다 보니까 부모들이 의료보험 적용을 받도록 해달라고 여러 군데를 쫓아다니면서 부탁을 해요. 그래서 제가 이러한 사고내용을 여러 건 보았습니다.  현재 작년에는 8건, 올해는 4건 이렇게 말씀하셨는데 이것은 제가 볼 때 전국적인 추세에 비해서는 너무 적은 숫자가 아니냐 이렇게 판단이 됩니다. 그래서 실적 위주로 통계를 내는 것은 문제가 있다고 지적을 하면서 전국에서 부탄가스 흡입을 하다가 청소년들이 사고를 당한 부분은 정확한 집계를 해주시기를 부탁드리고 여기에 고미제 첨가를 하는 부분이 지금 현재 사업이 되었습니까?
# Context: 저는 다른 부분은 서면질의로 대신하고자 하고 아까 사장한테 자료요구를 했습니다마는 아직 자료가 오지 않아서 간단하게 묻겠습니다.  청소년 부탄가스 흡입사건이 1년에 평균 몇 건 정도 됩니까? 96년에 20건, 97년에 17건, 98년에 8건, 금년 말 현재는 4건이 발생했습니다. 점차적으로 감소하고 있습니다. 이러한 통계자료는 경찰서에서 조사를 해서 가스안전공사로 넘어온 것입니까? 모든 가스사고는 저희들한테 신고도 들어오지만 경찰서하고 소방서하고 저희하고 한 라인이 되어 있습니다. 저희들도 신고번호가 119입니다. 제 지역구가 경남 진해인데 경남 진해에서 청소년들이 부탄가스 흡입을 하는 과정에서 담배를 피운다든지 해서 폭발사고로 인해 가지고 화상을 입고 심지어 목숨을 잃은 사례를 제가 여러 번 보았습니다. 제가 이것을 어떻게 알게 되었느냐 하면 이 친구들이 대개 가정적으로 원만하지 못 합니다. 그리고 재정적인 능력이 없다 보니까 사고가 난 뒤에도 의료비를 낼 수가 없어요. 그러다 보니까 부모들이 의료보험 적용을 받도록 해달라고 여러 군데를 쫓아다니면서 부탁을 해요. 그래서 제가 이러한 사고내용을 여러 건 보았습니다.  현재 작년에는 8건, 올해는 4건 이렇게 말씀하셨는데 이것은 제가 볼 때 전국적인 추세에 비해서는 너무 적은 숫자가 아니냐 이렇게 판단이 됩니다. 그래서 실적 위주로 통계를 내는 것은 문제가 있다고 지적을 하면서 전국에서 부탄가스 흡입을 하다가 청소년들이 사고를 당한 부분은 정확한 집계를 해주시기를 부탁드리고 여기에 고미제 첨가를 하는 부분이 지금 현재 사업이 되었습니까? 고미제 첨가가 98년도 7월1일 이후로 의무화하도록 되어 있었습니다. 그런데 그 내용이 고미제가 일반 부탄가스에 혼합이 안 됩니다. 혼합이 안 되고 석출현상이 일어나기 때문에 전혀 효용가치가 없었습니다. 그래서 현재 중단한 상태고 다른 어떤 별도의 고미제 첨가를 조사ㆍ연구하고 있습니다. 그것이 작년에도 조사ㆍ연구한다고 그랬고 아직까지도 조사 연구고…… 그런데 아직까지 거기에 적합한 물질을 발견을 못하고 세계적으로 사용한 경우가 없었습니다. 이것이 어느 기관하고 같이 용역을 해서 조사를 하고 있습니까? 최초의 고미제는 SK가 발명했었습니다. 그 발명한 제품을 활용하기 위해서 저희들이 일제히 사용하도록 했는데 그 내용들이 실제 제조공장의 혼합과정에서 배합이 안 됩니다. 배합이 안 되고 석출현상이 생겨서 사용할 수가 없기 때문에 중단하고 각국에 이런 자료들을 저희들이 요청을 하고 알아보고 있는데 세계적으로 부탄가스에 고미제를 혼합한 나라가 하나도 없었습니다. 사장한테 당부드리겠습니다.  이것이 우리 청소년들을 위해서도 매우 중요한 문제이고 부탄가스 제조업체도 사실은 책임이 있습니다. 그리고 흡입하는 청소년들의 부모도 책임이 있습니다.  그러나 제일 궁극적으로는 국가 책임입니다. 그렇게 생각을 하면 이것이 작년 국감 때도 문제가 되었고 해마다 피력되었던 문제인데 이것을 사장께서 특별히 관심을 가지시고 청소년들이 부탄가스를 흡입할 수 없도록 고미제 외에 여러 가지 방안을 강구해서 대책을 수립해 주시기를 특별히 당부드리겠습니다.
# Answer: 고미제 첨가가 98년도 7월1일 이후로 의무화하도록 되어 있었습니다. 그런데 그 내용이 고미제가 일반 부탄가스에 혼합이 안 됩니다. 혼합이 안 되고 석출현상이 일어나기 때문에 전혀 효용가치가 없었습니다. 그래서 현재 중단한 상태고 다른 어떤 별도의 고미제 첨가를 조사ㆍ연구하고 있습니다.
# Question: 그러니까 내가 아까 얘기한 부산지검의 명예를 회복하기 위해서 해야 된다는 얘기이고 그 이전의 지검 검사장도 이 지역사회에서 유착되었다는 설도 여기에서는 널리 유포되어 있었습니다. 그런데다가 최근에 두 지검 검사장이 이 사건의 변호인으로 선임되고 하니까 점점 부산지검은 다대ㆍ만덕사건에 관한 한 처음부터 수사를 못 하게 되어 있는 사건이다, 내가 아까 말한 대로 국정감사 때마다 요구하고 추궁하고 또 감사원 감사가 착수되고 하니까 할 수 없이 등 떠밀려서 마지못해서 하는 것 아니냐 하는 것입니다.  수사진은 왜 교체했습니까?
# Context: 한 가지만 여쭈어 보겠습니다.  먼저 전임 지검 검사장 두 분이 다대ㆍ만덕사건으로 구속기소된 피고인의 변호인으로 선임되어 있다는데 그것이 사실입니까? 예, 그렇게 알고 있습니다. 저는 이 얘기를 듣고 물론 법적으로는 모르겠습니다마는 두 전임 검사장 중의 한 분은 2년 전 바로 이 국정감사장에서, 그 당시 감사원 감사가 착수될 시기였습니다. 그래서 감사원 감사가 끝나면 수사에 착수할 용의가 있는가, 철저한 수사촉구를 저뿐만 아니고 다른 여야위원들이 했습니다. 그때 분명히 여기서 감사원 감사가 끝나면 철저한 수사에 착수하겠다고 답변했습니다.  그런데 그 본인이 재직하던 지검에서, 수사ㆍ지휘하던 사건에 어떻게 변호인으로 선임됩니까? 이것은 정말 도덕적으로 윤리적으로 어떻게 이럴 수가 있습니까? 뒤에 후배검사들 여러분들 있는데 그 후배검사들을 봐서도 수사를 담당했던…… 어떻게 그렇게 할 수 있는지, 그래 가지고 구속기소된 주택조합의 두 사람이 이번에 보석이 되었다고 하는데 맞지요? 지난번에 보석되었습니다. 그러면 일반 국민의 입장에서 과연 이것이 정상적인 변론ㆍ변호활동에 의해서 이렇게 되었다고 보겠습니까? 그리고 한 사람의 변호인은 전 부산고법원장이 선임되어 있데요, 어떻게 직접 수사지휘를 했던 검사장인데 그럴 수가 있습니까? 그분들하고 얘기해 보신 적 없으세요? 다대ㆍ만덕사건의 주범이라기보다는 신용금고의 관련자를 선임한 것을 알고 있습니다마는 위원님께서 지적하신 문제점이 있습니다. 그래서 본인한테 위원님의 걱정을 정확히 전달하도록 하겠습니다. 그러니까 내가 아까 얘기한 부산지검의 명예를 회복하기 위해서 해야 된다는 얘기이고 그 이전의 지검 검사장도 이 지역사회에서 유착되었다는 설도 여기에서는 널리 유포되어 있었습니다. 그런데다가 최근에 두 지검 검사장이 이 사건의 변호인으로 선임되고 하니까 점점 부산지검은 다대ㆍ만덕사건에 관한 한 처음부터 수사를 못 하게 되어 있는 사건이다, 내가 아까 말한 대로 국정감사 때마다 요구하고 추궁하고 또 감사원 감사가 착수되고 하니까 할 수 없이 등 떠밀려서 마지못해서 하는 것 아니냐 하는 것입니다.  수사진은 왜 교체했습니까? 인사가 된 것이 금년 2월인데 그때는 이영복이가 이미 도주했고 나머지 사람들에 대해서는 1월 중에 다 기소된 뒤였습니다. 그렇기 때문에 정기인사에 따라서 부장검사가 서울로 갈 차례이고 또 수사검사는 부부장으로 승진을 하게 되어 있었습니다.  저희들 관행에 따르면 부부장검사로 승진을 하면 다른 청에 가게 되어 있습니다. 그렇게 해서 가기는 했습니다마는 후임 부장이나 후임 검사들의 수사열의는 또 수사에 대한 파악도는 전임자들에 결코 못지않다는 것을 말씀드립니다. 그러나 그것도 이 지역사회나 시민단체 등등에서는 크게 오해하고 문제를 삼았고 지금도 그런 것 아닙니까? 그렇습니다. 그러니까 내가 당부드리는데 내년에 또 국정감사 와서 얘기하지 않도록 부산지검의 명예와 전체 검찰의 명예를 걸고 이 사건을 공개하세요.
# Answer: 인사가 된 것이 금년 2월인데 그때는 이영복이가 이미 도주했고 나머지 사람들에 대해서는 1월 중에 다 기소된 뒤였습니다. 그렇기 때문에 정기인사에 따라서 부장검사가 서울로 갈 차례이고 또 수사검사는 부부장으로 승진을 하게 되어 있었습니다.  저희들 관행에 따르면 부부장검사로 승진을 하면 다른 청에 가게 되어 있습니다. 그렇게 해서 가기는 했습니다마는 후임 부장이나 후임 검사들의 수사열의는 또 수사에 대한 파악도는 전임자들에 결코 못지않다는 것을 말씀드립니다.
# Question: 이미 의약분업의 대원칙은 의사는 처방, 약사는 조제라는 직능의 분업으로 규정하였음에도 이익단체의 이해와 요구에 기초한 각 합의안의 경우 서로 주장을 수용하는 과정에서 누더기식으로 수정이 불가피하며 정부 단일안에 비해 분쟁의 소지가 더 클 수 있다는 것을 생각해 보신 적은 없습니까?
# Context: 高珍富 위원입니다.  車興奉 증인께 묻겠습니다.  현행 의약분업은 94년1월 개정된 약사법에 의해서 하신 것이지요? 그렇습니다. 94년 개정된 약사법 부칙에 보면 3년에서 5년 사이에 대통령이 정하는 날로부터 의약분업을 실시한다고 되어 있는데 그렇다면 의약분업의 시행은 바로 법률에 근거한 것이라고 볼 수 있지요? 그렇습니다. 누가 대통령이 되더라도 의약분업은 해야 하지요? 법률에 정해져 있고 대의명분이 있기 때문에 해야 되는 것으로 생각합니다. 車 증인께서는 1년에 3000억의 약가절감이 나와서 장기적으로는 재정에 플러스가 된다는 말을 많이 하셨지요? 그렇습니다. 그런데 車 증인께서는 의약분업으로 처방전이 노출되었을 때 의사들이 고가약을 처방한다는 사실은 몰랐습니까? 고가약을 처방할 것이라는 것을 일부 짐작은 했습니다마는 지금 이 정도로 크게 재정에 미칠 것이라고는 생각을 못 했습니다. 지금 고가약으로 한 7000억이 …… 고가약 부분이 처방일수의 변경으로 한 7000억 정도가 되는데 그 정도는 제가 예측을 못 했습니다. 지금까지 의약분업하기 전에는 약국만 이용하던 환자가 병원을 이용함으로써 어느 정도 적자가 날 것이라는 예상을 못 했습니까? 그 부분은 많은 검토를 한 부분입니다마는 예측이 빗나갔습니다.  기본적으로 약국을 이용하던 환자가 병원쪽으로 감으로써 약국에서 임의조제해서 약을 사먹던 많은 환자들의 주머니돈이 많이 절약된다고 보고 있고 저는 현재 그 효과가 나타난다고 보고 있습니다.  제가 추측하기에는 그것이 한 1조 이상이 될 것이라고 보여지는데 그것은 의료보험 재정하고는 아무 상관이 없이 국민의 주머니돈이 절약이 된 것입니다.  그리고 결국 그 환자들이 병원으로 와서 진찰하고 약을 받는 과정에서 의료보험 재정에 추가 영향을 미치는데 그것은 약국 환자가 병원에 얼마나 오느냐 하는 환자이동에 관한 문제인데 그 부분은 많은 변수와 상황에 따라 달라지기 때문에 수많은 전문가들하고 수많은 회의를 했습니다마는 예측하기가 정말 어려운 부분이었습니다.  그 예측이 빗나갔습니다. 제가 보기에는 고가약처방 문제하고 약국을 이용하던 사람이 병원으로 갔을 때의 상황을 예측을 못 한 것으로 알고 있는데 증인께서는 동의하십니까? 그렇습니다.  그 점에 대해서는 전적으로 동의합니다. 혹시 직업군 중에서 의약분업에 대한 전문가 집단을 꼽으라면 어느 직업을 꼽을 수 있겠습니까? 의약분업과 직접적인 관계 전문집단은 역시 의사․약사 집단이고 관련된 제약업체라든지 도매상이라든지 이런 것들이 이해관계집단이고 국민쪽에서 보면 국민의 이익과 관계되는 많은 시민사회단체도 관련단체라고 볼 수 있겠습니다. 본 위원은 의사나 약사들이야말로 의약분업의 당사자이자 전문가라고 생각하는데 동의하십니까? 그렇습니다. 의약분업 입법과정에서 당사자이자 전문가들이라고 할 수 있는 의사나 약사출신 의원님들의 의견이 얼마나 반영되었다고 보십니까? 약사법의 개정과정과 의약분업의 정책결정과정에서 그 당시에 의사, 약사 출신의 의원님들이 많이 계셨기 때문에 그분들의 의견이 많이 반영되었으리라고 생각합니다.  그 정책을 결정할 때는 저는 장관이 아닙니다. 여건 미숙과 준비부족 등으로 의약분업의 연기를 주장하신 분들이 계신 반면 조속한 시행을 주장하신 분들이 계신데 지금 생각해 보면 어떤 의견이 더 타당하다고 보십니까? 저는 시행하는 것이 잘 했다고 생각합니다. 시행한 것이 잘했다고 생각했는데 지금 국민들한테는 고통이 많습니다.  의약분업의 성공적 시행을 위한 준비를 위해 시행시기 연기를 주장하였다는 이유로 시민단체가 뽑은 낙천․낙선 대상에 오르거나 여러 가지 불이익을 감수한 분들이 많은 것으로 알고 있는데 당시 주장이 터무니없이 계획에 역행하는 주장들이었다고 보십니까? 당시에 의약분업에 대해 시행연기나 시행보류나 시범사업의 주장들이 많이 있었습니다마는 저는 지금도 그렇게 생각합니다마는 그 당시에 연기를 하거나 보류를 했으면 우리나라에서는 영원히 의약분업을 못 하게 되었을 것이라고 생각합니다. 2․3년 연기하는 것보다는 그때 하는 것이…… 그렇습니다. 즉, 졸속한 시행이 연기론보다 타당하다는 것이지요? 의약분업 자체의 대의명분과 역사적 의의로 봐서 다소 무리가 있다 손치더라도 그 당시에 시행하지 않았으면 영원히 우리나라에서 불가능했다고 생각합니다. 의약분업은 약사법에 규정된 사항입니다.  그럼에도 불구하고 정해진 법에 따라 이를 시행한 행정부가 보험재정 파탄에 대해 전적으로 책임을 져야 한다고 생각하십니까? 보험재정 파탄과 위기문제에 대해서는 원인 하나하나를 가려야 된다고 생각합니다.  그런데 그 원인이 아직 완전하게 규명이 안 되어 있기 때문에 그 원인에 따라서 정부가 책임질 부분도 있고 또 어떤 책임자가 책임질 부분도 있는데 그런 것들이 분석이 되어서 가려져야 된다고 생각합니다. 법안을 만든 국회와 의약분업 조기시행을 강력하게 추진한 분들도 어느 정도 책임이 있다고 생각하지 않습니까? 정책의 결정과정에서는 정치적인 결정이 많이 있었습니다.  그리고 국회에서의 입법과정이 있었기 때문에 그 부분에 대해서는 입법과정에서 책임을 질 일이고 행정부는 국회에서 정해준 법률을 가지고 집행하는 책임을 지고 있기 때문에 집행에 대해서는 행정부가 책임을 져야 된다고 생각합니다. 시민단체 중재안을 건의 받은 후 의약분업실행위원회를 구성하여 급속하게 의약분업을 전개한 것으로 알고 있는데 이 세부사항을 확정하는 과정에서 각 이익단체의 요구사항이 관철됨으로 인해서 의약분업의 근본취지가 손상된 것은 없습니까? 세부시행 과정은 99년5월10일 의료계․약계․시민단체의 합의에 기초해서 그것의 세부시행 방안을 만드는 것이었기 때문에 큰 테두리에서는 변경이 없었습니다.  다만 세부시행 과정에서 사소한 부분에 대해서는 각 이해단체의 주장이 있었고 또 많은 타협도 있었고 그렇게 해서 최종적으로 그 해 9월에 최후로 세부시행방안이 확정됐습니다.  그때 이해관계인의 주장이 많이 반영이 됐습니다. 이미 의약분업의 대원칙은 의사는 처방, 약사는 조제라는 직능의 분업으로 규정하였음에도 이익단체의 이해와 요구에 기초한 각 합의안의 경우 서로 주장을 수용하는 과정에서 누더기식으로 수정이 불가피하며 정부 단일안에 비해 분쟁의 소지가 더 클 수 있다는 것을 생각해 보신 적은 없습니까? 그후 세부시행 과정을 만드는 과정에서 이익집단의 이해관계에 따른 주장은 당연하다고 생각하고 다만 원칙적으로 의약분업의 처방과 대원칙은 5․10합의에 의해서 지켰다고 생각하고 그 5․10합의에 충실하려고 노력을 했습니다.  나중에 변경이 됐습니다마는 실행위원회의 과정에서는 그렇게 했습니다. 결국 그러한 분쟁의 소지가 많은 합의안 때문에 의료대란과 같은 집단행동이 야기되었다는 생각은 하지 않습니까?
# Answer: 그후 세부시행 과정을 만드는 과정에서 이익집단의 이해관계에 따른 주장은 당연하다고 생각하고 다만 원칙적으로 의약분업의 처방과 대원칙은 5․10합의에 의해서 지켰다고 생각하고 그 5․10합의에 충실하려고 노력을 했습니다.  나중에 변경이 됐습니다마는 실행위원회의 과정에서는 그렇게 했습니다.
# Question: 그다음 한국건설관리공사 민영화추진에 대해서 어제도 잠시 얘기를 했습니다마는 우리나라가 규제완화, 구조조정해서 건설시장에서 휴대폰회사가 판을 쳐대고 최저가낙찰제 이래서 그 부작용으로 인해서 부실시공이 연이어지고 있습니다.   또 민간 감리는 전부 같이 시공사 측의 변명으로만 일관하고 있는 이런 입장이 되어 있습니다. 그렇기 때문에 본 위원 생각은 한국건설관리공사등 4개 공사의 기술진들을 전부 모아서…… 지금 수주도 한 1100억 이상 남아 있고 현금도 400억 이상 있고 계속 흑자를 발생시키고 있기 때문에 국가의 기준이 되는 감리, 공공성을 지닌 감리자로 적어도 민간 감리가 성숙될 때까지 유지되어야 됩니다.  그런데 지금 기획예산처에서는 10월20일까지 건교부의 최종안을 제출토록 하고 있습니다. 그래서 건교부가 기획예산처의 압박에 의해서 방법이 없는 이런 상황에 놓여있습니다.   그래서 이것은 위원회에 법안도 들어와 있고 이번에 宋光浩 위원이나 저나 다른 모든 위원님들이 건설현장을 다니면서 여러 가지 부실에 대한 문제를 확인했기 때문에 민영화 문제는 적어도 어느 정도 민간 감리가 제대로 될 때까지는 유보를 시켜서라도 감리의 잣대는 있어야 되겠다 하는 것을 모든 위원님들이 지적하고 있는 것입니다.   차관, 건교부 최종안을 10월20일까지 제출토록 하라고 하는데 무조건 시키는 대로 건교부 채점 좀 떨어질까 싶어서…… 기획예산처는 건교부보다 훨씬 작은 기관입니다. 그런 기관에 질질 끌려 다녀서 일을 그르치지 마시고, 이 문제를 어떻게 하시겠습니까?
# Context: 그런데 직선지하화라고 말씀만 하시는데 지금 실제로 고속철도공단이라든지, 철도청이라든지 나머지 기술진들 또 우리나라 전문가인 교수들 얘기를 들어보면 대구 직선화, 대전 직선화…….   이것도 또 다릅니다. 대전은 변두리에 있기 때문에 대구하고 달라요. 대구는 현재 경부선이 있는데 옆에다 또 도심을 통과하게 직선지하화로 고속철도 노선을 만들어 놓았다 말입니다.   그런데 역사가 60m 밑으로 내려가면 일본의 우에노처럼 문제가 있다고 하는 지적이 나오고 대구의 토질이라든가 풍화암 이런 등등의 여건으로 봐서 과연 지하화가 될 것이냐 하는 데도 상당히 문제가 많다고 기술자들이 얘기하고 있다 이것입니다.   그러면 결과적으로 가만히 둬버리면 지상화할 수밖에 없잖아요? 기존선을 지상화해서 대구를 세 동강 내놓으면 대구 사람들은 다 어떻게 하라는 말이에요.  그래서 돌아가고 있는 모습들과 계획된 발상자체를 볼 때 한 도시의 미래를 도와주지는 못할망정 완전히 파괴할 단계에 왔기 때문에 본 위원은 염려스럽습니다. 대구는 대전하고 여건이 달라요. 하기 때문에 이 문제는 적어도 기초조사가 되었다면…….   협의하면 솔직히 용역 줄 것이 무엇이 있습니까? 지금 철도청이 기술이 없어요, 고속철도가 기술이 없습니까? 전부 기술자들 갖다 놓고 이 문제를 심도 있게 검토하면 용역비 안 줘도 되는 것 아닙니까? 자꾸 이런 식으로 해서는 안 되겠다 하는 얘기입니다.   단장은 들어가고 차관께서는 본 위원의 뜻을 충분히 헤아렸지요? 예, 알겠습니다. 그렇게 적당히 알겠습니다 하지 말고 앞으로 건설행정을 오래 맡아야 돼요. 정권이 바뀔 때도 남아있어야 돼요. 전부 거짓말 해놓고 다 나가버리면 누가 책임지는 것이에요?   하기 때문에 적어도 이런 문제는 어떤 지역의 사업을 가지고 지역이기주의로 얘기한다고 생각해서는 안 됩니다. 대전과 대구를 합쳐서 1조 2000억이 더 들어간다 그러면 대구는 7000억이 더 들어갑니다. 더 들어가더라도 국가적으로 3조나 5조 이상의 경제적 효과를 가져올 수 있다면 이것은 당연히 해야 되는 것입니다. 그것이 바로 경제논리입니다. 내가 정치논리로 하자는 얘기 아닙니다. 이 점에 대해서 이 시간 끝난 이후에는 깊은 관심을 가지고 실질적으로 움직일 수 있도록 독려해 주시고 지시해 주십시오. 아시겠습니까? 예, 잘 알겠습니다. 그다음 한국건설관리공사 민영화추진에 대해서 어제도 잠시 얘기를 했습니다마는 우리나라가 규제완화, 구조조정해서 건설시장에서 휴대폰회사가 판을 쳐대고 최저가낙찰제 이래서 그 부작용으로 인해서 부실시공이 연이어지고 있습니다.   또 민간 감리는 전부 같이 시공사 측의 변명으로만 일관하고 있는 이런 입장이 되어 있습니다. 그렇기 때문에 본 위원 생각은 한국건설관리공사등 4개 공사의 기술진들을 전부 모아서…… 지금 수주도 한 1100억 이상 남아 있고 현금도 400억 이상 있고 계속 흑자를 발생시키고 있기 때문에 국가의 기준이 되는 감리, 공공성을 지닌 감리자로 적어도 민간 감리가 성숙될 때까지 유지되어야 됩니다.  그런데 지금 기획예산처에서는 10월20일까지 건교부의 최종안을 제출토록 하고 있습니다. 그래서 건교부가 기획예산처의 압박에 의해서 방법이 없는 이런 상황에 놓여있습니다.   그래서 이것은 위원회에 법안도 들어와 있고 이번에 宋光浩 위원이나 저나 다른 모든 위원님들이 건설현장을 다니면서 여러 가지 부실에 대한 문제를 확인했기 때문에 민영화 문제는 적어도 어느 정도 민간 감리가 제대로 될 때까지는 유보를 시켜서라도 감리의 잣대는 있어야 되겠다 하는 것을 모든 위원님들이 지적하고 있는 것입니다.   차관, 건교부 최종안을 10월20일까지 제출토록 하라고 하는데 무조건 시키는 대로 건교부 채점 좀 떨어질까 싶어서…… 기획예산처는 건교부보다 훨씬 작은 기관입니다. 그런 기관에 질질 끌려 다녀서 일을 그르치지 마시고, 이 문제를 어떻게 하시겠습니까? 위원님, 민영화는 총론적으로 말씀드려서 정부가 또는 어떤 부처가 이기적으로 생각을 한다면 왜 민영화를 하겠습니다. 공영화를 해서 공기업으로 많이 가지고 있을수록 그 부처가 권한도 행사하고 일감도 있고 좋은 것 아니겠습니까?   그러나 국민적 요구는 시장기능에 맡길 것은 맡겨라 하는 것도 있다는 점을 이해해야 됩니다. 그래서 저희가 민영화하는 취지를 관련 기관들한테 충분하게 설득해 나가겠습니다. 그러나 제기되는 문제점이 있기 때문에 제기되는 문제점에 대해서 설득해 가면서…….   생각해 보십시오. 어느 정부기관이 자기가 가지고 있는 기관을 민영화하려고 그러겠습니까? 떼어내려고 하는 것은 다른 쪽에서 말하지 않은 많은 국민적 요구가 있기 때문에 그런 것이지 왜 그렇겠습니까? 그런 점을 이해해 주시기 바랍니다. 이해는 좋아요. 지금 국민적 요구가 있다고 그러는데 본 위원이 확인한 바로는 적어도 국가의 잣대가 될 수 있는, 국민이 투자한 공공성이 있는 기관의 사명감이 있는 기술자들이 철저한 감독을 당분간은 해야 되겠다는 것이 80%가 넘는 국민적 요구라는 사실도 건교부는 명심해야 됩니다.   그래서 10월20일에…… 국감이 끝나고 나면 바로 상임위원회가 열려서 우리가 법도 심의하고 여러 가지를 다루게 될 텐데 이 문제를 10월20일에 기획예산처가 시킨 대로 민영화에 동의한다 이렇게 경솔하게 하지만 마십시오. 참고하겠습니다. 10월20일에 하지 말라는 말이에요. 조금 더 검토하겠다고 신중하게 얘기하십시오. 알겠습니다. 적어도 10월20일은 좀 넘겨야 됩니다. 알았습니까? 예, 알겠습니다. 이상입니다.  나머지는 서면으로 질의하겠습니다.
# Answer: 위원님, 민영화는 총론적으로 말씀드려서 정부가 또는 어떤 부처가 이기적으로 생각을 한다면 왜 민영화를 하겠습니다. 공영화를 해서 공기업으로 많이 가지고 있을수록 그 부처가 권한도 행사하고 일감도 있고 좋은 것 아니겠습니까?   그러나 국민적 요구는 시장기능에 맡길 것은 맡겨라 하는 것도 있다는 점을 이해해야 됩니다. 그래서 저희가 민영화하는 취지를 관련 기관들한테 충분하게 설득해 나가겠습니다. 그러나 제기되는 문제점이 있기 때문에 제기되는 문제점에 대해서 설득해 가면서…….   생각해 보십시오. 어느 정부기관이 자기가 가지고 있는 기관을 민영화하려고 그러겠습니까? 떼어내려고 하는 것은 다른 쪽에서 말하지 않은 많은 국민적 요구가 있기 때문에 그런 것이지 왜 그렇겠습니까? 그런 점을 이해해 주시기 바랍니다.
# Question: 통계청이 홈페이지를 부적절하게 관리하고 있는 문제점은 통계 본청만이 아닙니다. 본 위원이 파악한 바로는 전남 통계사무소와 목포출장소가 자체적으로 관리하는 홈페이지도 관리소홀로 인해서 지난해 5월 통계청 자체 감사에서 주의처분을 받았습니다.  전남 통계사무소는 2년 전에 작성된 지역통계현황자료를 자체 홈페이지에 게재하였을 뿐만 아니라 작성이 중지된 통계자료를 홈페이지에서 제공하였습니다.   목포출장소는 민원인이 홈페이지에 신청한 민원을 한 달간 방치하여서 민원인이 대통령비서실에서 관리하고 있는 인터넷 신문고에 민원방치에 대한 민원을 제기하는 불상사도 발생했습니다.   이처럼 지난해 지방통계사무소의 홈페이지 관리 문제로 감사를 통해 주의처분을 받았음에도 불구하고 지방사무소를 관리해야 할 통계 본청마저 올해 시행된 홈페이지 품질평가에서 최하위를 차지했다고 하는 것은 통계청이 홈페이지 이용자들의 불만을 외면하고 있다고밖에는 볼 수가 없습니다.   통계청은 현재 인터넷 및 전자상거래 이용자의 증가추세에 따라 홈페이지 이외에 99년부터 통계 쇼핑몰을 개설해서 이용자가 필요로 하는 통계자료를 유료로 구입할 수 있는 수익사업을 전개하고 있습니다.   이런 상황에서 통계청이 홈페이지를 부실하게 관리하여 계속 지적을 받게 되면 이용자들의 신뢰를 잃게 되어서 결국 통계청은 통계상품을 판매하는 사업도 큰 타격을 입게 되고 말 것입니다.   통계청은 홈페이지 관리를 철저히 해서 이용자의 만족도를 높여야 한다고 본 위원은 생각하고 있는데 청장께서 홈페이지 관리 부실의 원인이 무엇인지 그리고 홈페이지 관리를 위해서 어떤 대책을 세우고 있는지 이 자리에서 간략하게 답변해 주시기 바랍니다.
# Context: 통계청이 예산도 부족하고 열악한 환경 속에서 청장 이하 여러분들이 고생하고 있는 줄을 잘 압니다.   오늘 내가 유감스럽게도 여러분에게 격려의 말씀과 함께 좀 나무라는 이야기를 해야 되겠습니다.   통계청은 인터넷의 통계청 홈페이지와 통계 종합 홈페이지를 개설해서 국민들에게 통계정보를 제공하고 있는데 지난 4월 민간업체들과 대학원이 공동으로 36개 행정부처의 홈페이지를 평가한 바가 있습니다. 그렇지요? 예. 이는 국내 최초로 시행된 정량적 웹사이트 품질평가로서 네비게이션을 비롯해서 사이트 접근성과 성능을 평가한 것으로 본 위원은 파악하고 있습니다. 그런데 36개 행정부처 가운데 16개 청을 대상으로 한 평가에서 통계청은 16위로 최하위를 기록했습니다. 통계청 홈페이지의 사이트 오류 때문에 이용자들의 불만도 크다고 발표되었습니다. 그렇지요? 그렇게 기사에 났습니다. 통계청이 홈페이지를 부적절하게 관리하고 있는 문제점은 통계 본청만이 아닙니다. 본 위원이 파악한 바로는 전남 통계사무소와 목포출장소가 자체적으로 관리하는 홈페이지도 관리소홀로 인해서 지난해 5월 통계청 자체 감사에서 주의처분을 받았습니다.  전남 통계사무소는 2년 전에 작성된 지역통계현황자료를 자체 홈페이지에 게재하였을 뿐만 아니라 작성이 중지된 통계자료를 홈페이지에서 제공하였습니다.   목포출장소는 민원인이 홈페이지에 신청한 민원을 한 달간 방치하여서 민원인이 대통령비서실에서 관리하고 있는 인터넷 신문고에 민원방치에 대한 민원을 제기하는 불상사도 발생했습니다.   이처럼 지난해 지방통계사무소의 홈페이지 관리 문제로 감사를 통해 주의처분을 받았음에도 불구하고 지방사무소를 관리해야 할 통계 본청마저 올해 시행된 홈페이지 품질평가에서 최하위를 차지했다고 하는 것은 통계청이 홈페이지 이용자들의 불만을 외면하고 있다고밖에는 볼 수가 없습니다.   통계청은 현재 인터넷 및 전자상거래 이용자의 증가추세에 따라 홈페이지 이외에 99년부터 통계 쇼핑몰을 개설해서 이용자가 필요로 하는 통계자료를 유료로 구입할 수 있는 수익사업을 전개하고 있습니다.   이런 상황에서 통계청이 홈페이지를 부실하게 관리하여 계속 지적을 받게 되면 이용자들의 신뢰를 잃게 되어서 결국 통계청은 통계상품을 판매하는 사업도 큰 타격을 입게 되고 말 것입니다.   통계청은 홈페이지 관리를 철저히 해서 이용자의 만족도를 높여야 한다고 본 위원은 생각하고 있는데 청장께서 홈페이지 관리 부실의 원인이 무엇인지 그리고 홈페이지 관리를 위해서 어떤 대책을 세우고 있는지 이 자리에서 간략하게 답변해 주시기 바랍니다. 홈페이지의 관리가 저희 통계청 업무에 결정적으로 중요한 생명이라고 하는 점에서 위원님께서 말씀하신 취지에 대해서 공감하고 있습니다.   저는 지난 4월 17일자 매경이코노미에 게재된 언론의 횡포에 대해서 언론중재위원회에 정식으로 제의해서 그로부터 사과를 받아냈고 정정보도를 정식으로 실은 바가 있습니다.   그 사람들이 통계청의 홈페이지를 평가한 것이 아니고 통계청이 만들어낸 영문 홈페이지를 국문 홈페이지를 평가하는 소프트웨어를 가지고 평가했기 때문에 엑세스가 안 된다는 식의 평가를 한 결과를 신문에 냈습니다.   그래서 우리 담당자가 가서 당신들이 이렇게 틀린 자료를 가지고 횡포를 할 수 있느냐 해서 정식으로 사과를 받아냈고 정정보도문을 실었습니다.   그러나 제가 그것을 강조해서 말씀드리는 것이 아니고 지금 나날이 늘어나고 있는 인터넷을 통한 통계수요의 증대에 비추어볼 때 통계청 홈페이지는 통계자료를 작성하는 것 못지않게 중요하니까 제대로 관리하라고 하는 위원님의 지적에 대해서 저도 명심하고 철저히 관리하도록 하겠습니다. 청장 이야기를 듣고 보니까 이해가 됩니다.   하여튼 앞으로 통계청에서 여러 가지 통계자료를 수집하는 문제라든지 홈페이지 관리하는 데 있어서 좀더 철저를 기해 주시기 바라고 제가 몇 가지 질의를 준비했습니다마는 나머지는 시간이 없으니까 서면으로 하도록 하겠습니다.
# Answer: 홈페이지의 관리가 저희 통계청 업무에 결정적으로 중요한 생명이라고 하는 점에서 위원님께서 말씀하신 취지에 대해서 공감하고 있습니다.   저는 지난 4월 17일자 매경이코노미에 게재된 언론의 횡포에 대해서 언론중재위원회에 정식으로 제의해서 그로부터 사과를 받아냈고 정정보도를 정식으로 실은 바가 있습니다.   그 사람들이 통계청의 홈페이지를 평가한 것이 아니고 통계청이 만들어낸 영문 홈페이지를 국문 홈페이지를 평가하는 소프트웨어를 가지고 평가했기 때문에 엑세스가 안 된다는 식의 평가를 한 결과를 신문에 냈습니다.   그래서 우리 담당자가 가서 당신들이 이렇게 틀린 자료를 가지고 횡포를 할 수 있느냐 해서 정식으로 사과를 받아냈고 정정보도문을 실었습니다.   그러나 제가 그것을 강조해서 말씀드리는 것이 아니고 지금 나날이 늘어나고 있는 인터넷을 통한 통계수요의 증대에 비추어볼 때 통계청 홈페이지는 통계자료를 작성하는 것 못지않게 중요하니까 제대로 관리하라고 하는 위원님의 지적에 대해서 저도 명심하고 철저히 관리하도록 하겠습니다.
# Question: 실제로 제가 입수한 자료에 의하면 1997년, 2000년 교육개발원에서 조사한 자료에 의하면 비평준화지역에 있는 학교들보다 평준화지역에 있는 학교들의 성적향상률이 높습니다. 상ㆍ중ㆍ하 다 그렇습니다. 성적이 좋았던 아이들이 향상된 정도, 중간이었던 아이들이 향상된 정도, 공부 못했던 아이들이 향상된 정도가 평준화지역이 비평준화지역보다 향상률이 더 높다는 이야기입니다.  그 이야기는 오히려 비평준화지역이 아이들의 교육환경과 교육현실을 왜곡시키는 문제가 더 많이 나타난다는 것입니다. 우수한 아이들만 모아 놓았을 때에도 자살을 한다거나 탈선을 하는 등의 문제가 발생하고, 못하는 아이들은 못하는 아이들대로 포기해버리는 문제들이 평준화지역에 비해서 비평준화지역이 더 심각하다는 이야기입니다.  교육감께서는 이 보도에 의한 것처럼 신도시지역에 대해 신빙성있는 조사를 실시해서 이 보도에 의한 것처럼 70% 이상의 학부모들이 이것을 원한다면 평준화지역으로 전환하실 의사가 있으십니까?
# Context: 任鍾晳 위원입니다.  자료준비와 국정감사를 직접 받으시느라고 많이 피로하실 줄 압니다. 심심한 위로와 감사의 인사를 함께 드립니다.   저는 시간내에 일문일답으로 하겠습니다. 혹시 부족한 것이 있으면 서면으로 하겠습니다.   먼저 인천교육청에 질의 드리겠습니다.   우리가 씨랜드에서도 볼 수 있듯이 학생안전권은 학습권이나 복지권보다 훨씬 중요하다고 생각합니다. 앞서 金貞淑 위원님께서 말씀하셨지만 학생들의 유치원, 초ㆍ중ㆍ고등학교의 통학버스가 종합보험 특별약관에 미가입된 차량들이 전국에 18.2%나 됩니다.   인천도 27.3%가 종합보험 특별약관에 미가입되어서 불의의 사고시 굉장한 피해가 염려되고 있습니다. 서울과 대구, 광주, 경기도는 미가입문제가 깨끗이 정리되어 있고 나머지 지역은 좀 많은 데도 있고 적은 데도 있습니다. 인천은 전국 평균보다 약 10% 높은데 이것을 즉시 해결하는데 어떤 어려움이 있습니까? 말씀드리겠습니다.   인천시내에 초등학교 버스 미가입은 공립의 경우는 없고 사립은 거의 해결됐고 대부분이 유치원입니다. 사립유치원의 버스는 미가입 상태가 많습니다. 고등학교도 꽤 있는데요? 현재 보험에 미가입된 상태는 없습니다. 이것은 제가 자료를 요청해서 받은 것인데 종합보험 특별약관에 인천지역은 중학교만 깨끗할 뿐 초등학교나 고등학교는 미가입 차량들이 있습니다.   공ㆍ사립 불문하고 이것을 즉시 가입시키는 행정조치를 하는데 어려움이 있습니까? 행정조치하는데 그렇게 어렵다는 것은 없는데 하여튼 현재 통계를 받았습니다마는 빠른 시일내에 가입되도록 노력하겠습니다. 이것이 유상운송허가를 받는데 어려움은 있습니다마는 그것은 운송사업법상의 문제이고 일단 이것은 종합보험 특별약관에 1대도 빠짐없이 가입할 수 있도록 즉각 조치해줄 수 있겠지요? 예, 알겠습니다. 이것은 미루지 말고 조치해 주시고 그 조치에 따른 결과를 11월3일까지 본 위원실로 보고해 주시기 바랍니다. 예, 알겠습니다. 그리고 인천에 국제복음학교가 있지요? 예. 2000년3월15일에 국제복음고등학교가 개교했습니다. 그런데 이 복음학교가 개교하면서부터 바로 말썽이 일어났습니다. 복음학교가 설립승인될 때부터 부정과 비리가 지속되어서 학교가 개교하면서 바로 2000년3월 이후에 교실과 교무실에 폐쇄되어서 강당수업을 실시했습니다. 이미 3월30일에 학교운영과 관련해서 시정명령을 교육청에서 내린 적이 있고 5월8일부터 19일까지 특별감사를 실시해서 굉장히 많은 내용에 대한 지시를 내렸습니다.   그리고 제가 7월27일자로 국정감사 자료를 요청하고 9월9일에 임시이사가 파견되었습니다. 그 이후에 여기에 대해서 어떤 정상화 계획을 가지고 계시는지 간단하게 말씀해 주십시오. 현재 관선이사가 파견되어 있고 내년도 학생을 수용하기는 도저히 어려울 것 같아서, 현재 2학급 인가를 신년도 1학급 모집으로 축소시켰습니다. 학교 설립 당시에 40명이었지요? 예. 현재 몇 명입니까? 20명입니다. 수업은 정상적으로 이루어지고 있습니다. 현재 임시이사가 파견되어 있고, 98% 국고보조로 운영되고 있지요? 인건비나 운영비가 전부 보조되고 있습니다. 제가 입수한 자료에 의하면 전체 운영의 98%가 국고보조에 의해서 이루어지고 있는 것으로 알고 있습니다.   현재 교육부 방침은 새로운 독지가가 학교를 인수해 줄 것을 기다리는 것이라고 알고 있는데 그렇습니까? 절충 중에 있으며 새로운 독지가가 나올 것으로 보고 그 독지가가 인수해 줄 것이라는 계획을 가지고 있습니다. 그런 독지가 후보를 알고 계시는 것입니까? 예, 절충 중에 있습니다. 대략 언제쯤이면 알 수 있습니까? 저쪽 답변을 들어봐야 되는데 금년내로 마무리될 것으로 보고 있습니다. 당연히 금년내에 되어야지요. 내년에 학생들을 받아놓고 대책이 없으면 어떻게 됩니까? 그렇다 하더라도 현재 운영비 인건비를 다 대고 있으니까 정상적인 운영을 하고 있습니다. 만약에 독지가가 안 나타날 경우에는 공립화합니까? 마지막에는 그런 방법도 연구해 보겠습니다. 그런데 이 인가를 승인하실 때 이렇게 부실한 상태라는 것이 사전에 전혀 파악이 안 됐습니까? 아니지요. 그전에는 모든 것이 정상적이었는데 인가해놓고 나서부터 상당히 파행적인 운영을 해온 것입니다. 일례로 이사회 회의록까지 위조했다는 문제까지 대두됐습니다. 이것을 빨리 잡지 않으면 안 되겠다는 생각에서 저희가 관선이사를 보내고 정상화노력을 하고 있는 것입니다. 이달 말까지는 새로운 독지가가 학교를 인수할 수 있을지 없을지 대략 결정할 수 있다는 말씀이지요? 예. 이것도 주요 진행상황에 대해서는 본 위원실로 자료를 보내주시기 바랍니다. 알겠습니다. 경기도교육청에 말씀드리겠습니다.  경기도 화성군에 방사성 동위원소 코발트60을 사용해서 식품처리를 하는 주식회사 서야라는 공장이 있는 모양인데 알고 계십니까? 예. 이 회사에서 다루고 있는 방사성 동위원소의 양이 꽤 많은데 이 회사가 인구밀집지역에 있습니다. 더군다나 100m 반경 안에 유치원이 하나 있고, 200m 안에 상신초등학교가 위치하고 있습니다. 그래서 현재 주민대책위가 구성되어서 굉장히 갈등이 많은 상황인데 저희가 이것을 들을 때까지는 경기도교육청과 화성군교육청이 이 사실을 잘 모르고 있는 것 같았습니다.   현재는 정확하게 인지하고 계신가요? 예, 정확하게 파악하고 있습니다. 이 문제는 화성군교육청에서 많은 관심을 가지고 피해가 없도록 조치하고 있다고 저는 그렇게 알고 있습니다. 방사성 동위원소 운반차량이 유치원 바로 앞길로 지나가고 있다고 하는데 그것도 알고 계십니까? 거기까지는 제가 잘 파악하지 못했습니다. 경기도 여주에도 같은 시설이 있는데 이 시설은 반경 1㎞ 안에 아무 것도 없습니다. 인구밀집지역에 더군다나 아이들의 교육시설이 있는 곳에 들어와 있는 것은 이례적인 경우지요? 물론 이것을 교육청이 허가하는 사항은 아닐 것입니다. 그렇지만 주민대책위에서 학생들의 등교거부를 계획하고 있는 것으로 제가 듣고 있습니다. 머지 않아 교육부 문제로 비화될 가능성이 높습니다.   여기에 대해서 앞으로 어떤 조치를 취하시겠는지 즉답이 가능하면 해주시고 안 그러면 답변시간에 해주시기 바랍니다. 제가 아는 범위 내에서 말씀드리겠습니다.  화성 건은 현재 화성군교육청에서 이 공장허가를 취소하였습니다. 그래서 공장가동이 중지된 상태로 있습니다. 그러면 그 공장시설을 완전히 이전할 수 있겠네요? 그래서 화성군청하고 소송관계가 진행되고 있는 것으로 알고 있습니다. 하루라도 빨리 이 문제가 종결될 수 있도록 교육부가 관계기관에 협조를 더 강하게 요청하셔서 지금 현재 주민대책위가 계획하고 있는 학생들의 등교거부같은 사태가 일어나지 않도록 신경을 써주시기 바랍니다. 예, 그렇게 하겠습니다. 경기도지역은 수원과 성남 이외에는 비평준화지역이지요? 그렇습니다. 그런데 최근 교육개발원에서 실시한 여론조사에 의하면 일산ㆍ분당ㆍ안양ㆍ부천 등지에서 학부모들의 70% 이상이 평준화지역으로 전환해 줄 것을 요청한다는 신문보도가 난 적이 있습니다. 보셨습니까? 예, 봤습니다. 실제로 제가 입수한 자료에 의하면 1997년, 2000년 교육개발원에서 조사한 자료에 의하면 비평준화지역에 있는 학교들보다 평준화지역에 있는 학교들의 성적향상률이 높습니다. 상ㆍ중ㆍ하 다 그렇습니다. 성적이 좋았던 아이들이 향상된 정도, 중간이었던 아이들이 향상된 정도, 공부 못했던 아이들이 향상된 정도가 평준화지역이 비평준화지역보다 향상률이 더 높다는 이야기입니다.  그 이야기는 오히려 비평준화지역이 아이들의 교육환경과 교육현실을 왜곡시키는 문제가 더 많이 나타난다는 것입니다. 우수한 아이들만 모아 놓았을 때에도 자살을 한다거나 탈선을 하는 등의 문제가 발생하고, 못하는 아이들은 못하는 아이들대로 포기해버리는 문제들이 평준화지역에 비해서 비평준화지역이 더 심각하다는 이야기입니다.  교육감께서는 이 보도에 의한 것처럼 신도시지역에 대해 신빙성있는 조사를 실시해서 이 보도에 의한 것처럼 70% 이상의 학부모들이 이것을 원한다면 평준화지역으로 전환하실 의사가 있으십니까? 평준화문제는 지금 성남ㆍ분당지역, 고양ㆍ일산지역, 안양지역, 부천지역 그 외에 이삼개 지역해서 7개 지역에서 학부모들이 평준화를 원하고  ...
# Answer: 평준화문제는 지금 성남ㆍ분당지역, 고양ㆍ일산지역, 안양지역, 부천지역 그 외에 이삼개 지역해서 7개 지역에서 학부모들이 평준화를 원하고 계시는데 반대하는 학부모도 많이 있습니다.   그래서 이것은 우리 교육청 단독으로 정책을 결정하기가 너무나 어려운 일이기 때문에 금년 초에 한국교육개발원에 용역을 주어서, 오늘 이 시간에도 안양지역에서 공청회가 이루어지고 있는 것으로 알고 있습니다. 11월 말에 보고자료가 저희에게 오면 면밀히 검토해서 내년 초에 정책을 결정하려고 생각하고 있습니다.
# Question: 지금 원장님께서 부분적이나마 답을 하시는 것을 들으면서 상당히 문제가 있다는 생각이 듭니다. 지금 문예진흥원 체제에서 문예진흥기금을 운용하는 데 있어서 원장 단독으로 결정하는 것이 아닙니다. 그렇지 않습니까? 문예진흥기금심의위원회가 있어서 심의해 왔습니다.   문예진흥원 체제를 문화예술위원회 체제로 바꾸려는 취지는 지금 원장께서 생각하시고 있는 것하고는 엄청난 차이가 있어요. 그런 가치관을 가지고 이것을 바꾸시려고 하는 데 문제가 있습니다. 현재 문예진흥원 체제에서는 아직까지 모든 권한이 문화관광부장관에게 있고 문화관광부장관의 감독을 받는 상황에서 자율적으로 운영되지 않고 있는 그 고리를 끊기 위해서 문화예술위원회로 전환하려는 것이지 절대로 문예진흥기금을 원장 독단적으로 심의하고 결정했기 때문이 아닙니다. 문화관광부에 예속되어 있기 때문에 전환하려고 하는 것이에요.  그런 의지를 가지고 접근하셔야지 지금 말씀하시는 것을 보면 원장 단독으로 하는 것보다는 11인 위원회를 구성해서 하는 것이 더 나을 것이다 하는 이런 접근방법은 잘못된 것입니다. 어떻게 그런 가치관을 가지고 문화예술위원회로의 전환을 시도하십니까?
# Context: 감사를 계속하겠습니다.  답변을 듣도록 하겠습니다.  문화예술진흥원장 답변해 주시기 바랍니다. 답변은 자리에 앉아서 해 주십시오.  다시 한번 거듭 부탁을 드립니다만 한 위원님당 두 가지 핵심적인 질의에 대해서만 우선 답변을 해 주시고 간략하게 핵심만 짚어서 답변을 해 주시면 고맙겠습니다. 존경하는 裵基善 위원장님 또 많은 위원님들께서 본인이 취임하여 일하는 과정에서 가장 크게 닥쳤던 문제들을 진지하게 제기해 주셔서 앞으로 일하는 데 큰 가르침을 주신 것에 대해서 대단히 감사하게 생각합니다.  먼저 가장 큰 현안 문제인 기금확보 방안에 대해서는 정말 우리나라 문화예술을 걱정하는 큰 마음의 눈으로 그 대처방안을 제기해 주셨습니다. 그런데 솔직히 말해 진흥원을 책임지고 있는 제가 뚜렷한 방안을 확인하여 제시하지 못한 점을 대단히 송구스럽게 생각합니다. 여기에는 제가 해결하기에는 너무 큰 제도적 문제, 즉 법률적 문제가 내재해 있고 행정부의 대통령을 비롯한 주무 장관의 특단의 결단이 필요한 사항이기 때문입니다.  그러나 이러한 문제를 오직 외부의 문제로만 생각하지 않고 저희 80여 명의 직원들은 위원님들의 정성 어린 우려와 걱정에 부응하여 최대한 그 방안을 모색하고 있고 저 또한 나름대로 최대한 힘을 기울여 문화예술인들과 함께 이 문제를 해결해 나가고자 하고 있습니다. 이 점을 감안하시고 위원 여러분들의 지속적인 관심을 정중하게 간청하는 바입니다.  한 가지 특히 이해를 구하고 싶은 것은 위원님들의 질의 중에 심의위원 구성 관련 부분입니다. 본인 부임 이후에 일어난 일이기 때문에 일일이 답변드리지 못한 것을 양해해 주셨으면 감사하겠습니다.  高興吉 위원님, 鄭鎭碩 위원님, 申榮均 위원님, 金秉浩 위원님, 尹鐵相 위원님, 權五乙 위원님, 沈載權 위원님, 金一潤 위원님께서는 위원회 11명을 장관이 모두 임명할 경우에 현재 장관의 코드식 인사를 우려하시면서 특정 계파 위주로 선임될 것을 걱정해 주셨고 그럴 경우 기금이 특정 단체로 편중될 우려가 있지 않느냐 그리고 위원 11인에게 모든 권한이 집중되는데 이럴 경우 특정 세력의 장악 의도가 아닌지, 새 판짜기의 일환이 아닌지를 지적하셨습니다.  金成鎬ㆍ辛基南ㆍ鄭東采ㆍ沈載權 위원님은 위원회의 필요성에 대해서 얘기하시면서 민간위원회 전환 시 일부 문화예술계에서 우려하고 있는 문제점의 보완대책에 대해서 물으셨습니다.  鄭柄國 위원님께서는 문화예술 분야는 다양한 장르로 되어 있는데 위원회에 장르별로 한 명씩 참여할 경우 대표성과 원활한 운영에 의문을 나타내 주셨으며 기금 확보도 안 되어 있는데 민간위원회로 갈 경우 재원 확보가 더 어렵지 않겠느냐고 말씀하시면서 의견수렴 과정을 물으셨습니다.  金秉浩 위원님께서는 위원회로의 전환이 민간자율보다는 정부의 통제를 강화하는 것이 아니냐고 말씀하셨습니다.  尹鐵相 위원님께서는 기금 운용의 공공성과 책임성에 대한 보장 방안에 대해서 물으셨습니다.  鄭柄國ㆍ高興吉ㆍ鄭鎭碩ㆍ申榮均ㆍ姜申星一ㆍ權五乙ㆍ金一潤 위원님께서는 진흥원 인사와 관련된 우려의 말씀을 하셨습니다.  그리고…… 원장님, 문화예술위원회로의 전환과 관련해서는 전 위원들이 전체적으로 질의했으니까 일일이 그 질의를 반복하지 마시고 전체적으로 문예진흥원의 문화예술위원회로의 전환과 관련해서 위원님들이 전반적으로 문제 제기한 부분에 대해서 입장 정리를 해 가지고 설명해 보세요. 예.  이러한 질의를 해 주셨는데 거기에 대한 답변을 하도록 하겠습니다.  지금까지의 논의에서 여야를 막론하고 대부분 위원님께서는 위원회 체제에 대한 취지에는 동감한다고 말씀하셨습니다. 다만 거기에서 파생되고 있는 여러 가지 문제점을 지적해 주셨습니다.  사실 위원회 문제는 지금의 문제가 아니고 몇 년 전서부터 진흥원 밖에서 논의되어 왔고 또 대통령 공약사업이기도 하고 그래서 많은 사람들이 문예진흥원의 문제점에 대해서 의식을 같이 하고 있고 개혁을 해야 된다는 공감대가 이루어진 것으로 알고 있습니다.  그렇기 때문에 우리가 위원회로 가자고 문화관광부와 같이 의논하면서 결정했을 때는 일단 이 정권, 이 정부의 출범 시기에 어떤 개혁의 의지가 있고 열정과 약간의 흥분도 있을 때 빨리 이 법안을 초안이나마 우선 골격을 만들어서 법안을 만들고 난 다음에 한 1년 동안 시간이 있을 테니까 그동안에 시행령과 시행세칙 가지고 의논하면서 그 뼈대에 살을 붙여 나가자는 생각으로 좀 조급하게 이 개정안을 밀고 나갔던 것이 사실입니다.  그래서 사실 이 법안이 올해 통과되기를 바랐던 것이지요. 그러니까 지금 9월 국회에 이 개정안이 상정되기를 바랐습니다. 그렇지 않고서 때를 놓치면 내년에 총선이 있고 그래서 이 개정안이라는 것이 한없이 유예될 것이기 때문에 본의 아니게 조급하게 이 일을 처리하게 되었던 것을 대단히 죄송스럽게 생각합니다. 그래서 그 조급성 때문에 그 비전이나 내용들이 일반 예술인들이나 또는 국회의원 여러분들께도 제대로 알려지지 않는 불찰을 우리가 저질렀습니다.  그러나 우리 진흥원이 밖에서 볼 때는 30년 동안 오는 동안에 고여 있는 부분이 있고 관료주의적으로 정체성이 있고, 문화와 예술을 다루는 것은 자유와 자율성에 입각한 것이고 또 그것에 대한 업무를 하는 데 있어서도 그 직원들의 자유와 자율성이 확보되어야 되는데 우리 직원들 그리고 문예진흥원의 시스템 자체가 경직되어 있었다는 것은 밖에서 지적되어 왔던 것입니다.  그래서 앞으로는 문예진흥원이나 문화관광부가 국민에 대한 시혜자가 아닌 예술인과 국민을 위한 서비스 정신이 투철한 매니저 역할을 해야 된다는 생각으로 위원회 전환의 타당성을 확인한 바 있습니다.  사실 사회가 민주화됨으로써 다양한 가치관 아래 문화예술의 형식도 매우 다양해 졌습니다. 그래서 문예진흥원의 굳어진 옛 틀을 가지고는 다원화된 사회를 반영하고 있는 예술을 감쌀 수 없고 적응하기가 어려운 상태입니다. 따라서 부득불 체질개선을 해야 되는 것입니다.   그리고 또 사회가 민주화되면서 점차 국민 대중들의 여러 장르의 예술을 향유하려는 욕구가 무척 높아지고 있습니다. 더군다나 주5일근무제가 실시되면 늘어나는 국민의 여가시간을 사행적이거나 불건전한 오락으로 채울 수는 없고 예술과 문화 형식으로 채워야 한다고 생각할 때 이 모든 것을 껴안을 수 있는 조직은 위원회밖에 없다고 생각합니다.  아무튼 그렇게 취지가 좋음에도 불구하고 그동안 너무 졸속으로 일을 해서 세간의 오해를 받고 있는데 그것은 단순한 오해일 뿐이라고 생각합니다. 특히 지금 문제가 되고 있는 문화관광부 산하의 기관장 인사의 편향성 문제와 위원회로 가는 문제는 전혀 별개의 문제인데도 같이 감으로 해서 위원회로 가는 것이 마치 부정적인 일인 양 비쳐지고 있는 현상에 대해서 대단히 안타깝게 생각합니다.   저는 연극인 100인의 성명을 읽고 이렇게도 오해가 심하구나 하는 것을 느꼈습니다마는 저희는 어떤 일을 함에 있어서 패거리를 만들지 않고 공평하게 선의적으로 일을 해 보고자 했는데 이렇게 악의 있는 사람처럼 보도되고 있는 것에 대해서 너무나 안타까움을 금할 수 없었습니다.  앞으로도 1년여의 많은 시간이 있으니까 그동안에 위원회 체제로 가는 일에 있어서 총론이 아닌 각론에 해당되는 부분을 확보하기 위해서 애를 쓰겠습니다. 특히 위원님들께서 편향된 인사문제와 관련해서 말씀해 주신 부분이 위원회 구성방식인데 지금 문예진흥원은 원장 독임제하에 있습니다. 원장님, 지금 장황하게 설명을 하시는데 제가 잘 이해를 못해서 그런지 모르겠지만 무슨 말씀을 하시는지 내용이 너무 길어서 잘 모르겠으니까 짧은 시간에 간단하게 핵심을 이야기하십시오. 그러면 11인 위원회에 대해서 말씀드리겠습니다. 장관이 원장 한 사람을 임명하는 것과 11인의 위원을 임명하는 것을 견주어 생각할 때 여러 가지 모순이 있을 수 있는 한 사람을 임명하는 것보다는 복수로 11명을 임명하는 것이 오히려 권력이 분산되지 않겠느냐 이렇게 생각합니다. 원장님 지금 이 자리는 문화예술위원회 관련 입법에 대한 공청회 장이 아닙니다. 그러니까 원장님이 이 부분에 대해 사안별로 일일이 다 의견을 개진해서는 아무런 의미가 없어요.  여기서 많은 위원님들이 입법예고된 안에 대해서 말씀하시는 것은 많은 문화예술인들이 ...
# Answer: 문예진흥기금은 문예진흥원이 관리하고 있습니다마는 이것은 국민의 것이고 정부가 이 국민의 기금을 사용하는 것을 감독할 정당한 권리가 있습니다. 그 정부를 대표해서 문화관광부가 있고 우리 문예진흥원이 사업 또는 정책을 결정할 수 있도록 개정법에 되어 있습니다.  따라서 문화관광부가 여기에 대해서 어느 정도 간섭을 한다는 것은 당연한 일이라고 생각합니다. 그러나 그것은 불가분의 관계이지 어떤 종속관계가 아니고 파트너십 관계로 가는 것이 이 법안의 골자입니다.
# Question: 사장께 묻습니다.  서해안고속도로 평택-서울 구간의 교통 지ㆍ정체를 해소하기 위해서는 확장계획이 조속히 수립되어야 할 것으로 판단되는데 이에 대한 대책이 무엇인지 답변하여 주시기 바라고 또한 서평택-일직 간 확장 타당성조사를 금년 8월부터 시작한 것으로 알고 있는데 이번 조사에서 서평택-당진 구간도 교통분석을 정확하게 실시해서 확장의 타당성을 조사해야 할 필요가 있다고 생각하는데 이에 대한 사장의 견해를 밝혀 주시기 바랍니다.  그리고 업무현황과 관련한 내용을 한 가지 질의하겠습니다.  업무현황에 보면 당진-대전 간 고속도로 건설사업 시행기간이 2001년부터 2008년까지로 되어 있는데 지난 2월 19일 열린 239회 국회(임시회) 상임위원회 당시 吳 사장께서 답변하신 것을 회의록에서 보면 “금년부터는 공사 추진여건이 조성되어 본격적으로 공사를 추진할 계획이고 나아가 정부의 연도별 적정 예산지원이 있을 경우 2006년 말 개통은 가능할 것으로 판단된다”고 답변한 바 있습니다.  이 답변은 해석하기에 따라서 매우 애매한 결론이 도출됩니다. 즉 정부가 예산을 확보해 주면 하겠다는 지극히 수동적인 입장만을 보인 것이고 결과적으로 도로공사는 의례적인 답변을 했을 뿐 완공시기를 앞당기려는 노력을 전혀 기울이지 않겠다는 의미로도 해석될 수 있는 것입니다.  그런 증거가 바로 업무현황에도 나타나 있는 것으로 해석할 수 있습니다. 어제 건교부 국감에서도 본 위원이 장관에게 완공시기를 앞당길 것을 재차 촉구했습니다. 장관도 2006년 개통될 수 있도록 최대한 노력하겠다는 답변을 하셨습니다.  2008년 완공계획을 2006년으로 앞당기기 위해서 사장께서 앞으로 어떤 노력을 기울일 생각인지 답변해 주기 바랍니다.  사장님, 지난번에 말씀하신 것과 관련해서 2006년까지 앞으로 3년 반 정도가 남아 있습니다. 그리고 지금도 20% 정도는 공사 진척이 되어 있기 때문에 많은 노력을 할 경우에 충분히 2006년 말에 완공될 수 있다고 생각하는데 사장은 어떻게 생각하십니까?
# Context: 충남 당진 출신 宋榮珍 위원입니다.  吳鉆祿 사장님 그리고 임직원 여러분 국감 준비에 수고가 많다는 인사말씀을 드리면서 먼저 서해안고속도로 평택-서울 간 교통 지ㆍ정체 해소대책에 대해서 질의하겠습니다.  정부가 1992년에 수립한 국가간선도로망 계획을 보면 2002년까지 6160㎞의 간선도로 건설을 계획하고 있으며 본 위원이 파악한 바에 따르면 현재까지 구축된 도로망이 고속국도 및 자동차전용 국도를 포함하여 2823㎞에 달하는 것으로 알고 있습니다. 그런데 도로망은 마치 술래잡기라도 하듯이 새로 신설하고 기존 노선을 확장해도 계속해서 막히고 있는 실정입니다.  국민생활 향상에 따라 자동차 보유대수가 날로 증가하고 있고 또한 생활권역 확대로 인해서 고속도로 이용 교통량이 급증하고 있어서 일부 구간에서는 교통 지ㆍ정체가 여전히 발생하고 있는 것으로 분석되고 있습니다.  특히 서해안고속도로는 2001년에 전 구간이 개통되었는데도 최근 주5일 근무 시행이 확대되면서 서해안의 관광수요가 급증하여 주말의 경우 평택에서 서울까지는 항상 교통 지ㆍ정체가 발생하고 있는 실정입니다. 게다가 현재 공사 중인 안성-음성 간 그리고 대전-당진 간, 공주-서천 간 고속도로가 개통되면 서해안고속도로 이용량이 증가하게 되어 교통 혼잡에 따른 물류비용 증가는 더욱 가중될 것으로 예상하지 않을 수 없습니다.  사장께서도 이러한 사정을 알고 계시지요? 예, 그렇습니다. 사장께 묻습니다.  서해안고속도로 평택-서울 구간의 교통 지ㆍ정체를 해소하기 위해서는 확장계획이 조속히 수립되어야 할 것으로 판단되는데 이에 대한 대책이 무엇인지 답변하여 주시기 바라고 또한 서평택-일직 간 확장 타당성조사를 금년 8월부터 시작한 것으로 알고 있는데 이번 조사에서 서평택-당진 구간도 교통분석을 정확하게 실시해서 확장의 타당성을 조사해야 할 필요가 있다고 생각하는데 이에 대한 사장의 견해를 밝혀 주시기 바랍니다.  그리고 업무현황과 관련한 내용을 한 가지 질의하겠습니다.  업무현황에 보면 당진-대전 간 고속도로 건설사업 시행기간이 2001년부터 2008년까지로 되어 있는데 지난 2월 19일 열린 239회 국회(임시회) 상임위원회 당시 吳 사장께서 답변하신 것을 회의록에서 보면 “금년부터는 공사 추진여건이 조성되어 본격적으로 공사를 추진할 계획이고 나아가 정부의 연도별 적정 예산지원이 있을 경우 2006년 말 개통은 가능할 것으로 판단된다”고 답변한 바 있습니다.  이 답변은 해석하기에 따라서 매우 애매한 결론이 도출됩니다. 즉 정부가 예산을 확보해 주면 하겠다는 지극히 수동적인 입장만을 보인 것이고 결과적으로 도로공사는 의례적인 답변을 했을 뿐 완공시기를 앞당기려는 노력을 전혀 기울이지 않겠다는 의미로도 해석될 수 있는 것입니다.  그런 증거가 바로 업무현황에도 나타나 있는 것으로 해석할 수 있습니다. 어제 건교부 국감에서도 본 위원이 장관에게 완공시기를 앞당길 것을 재차 촉구했습니다. 장관도 2006년 개통될 수 있도록 최대한 노력하겠다는 답변을 하셨습니다.  2008년 완공계획을 2006년으로 앞당기기 위해서 사장께서 앞으로 어떤 노력을 기울일 생각인지 답변해 주기 바랍니다.  사장님, 지난번에 말씀하신 것과 관련해서 2006년까지 앞으로 3년 반 정도가 남아 있습니다. 그리고 지금도 20% 정도는 공사 진척이 되어 있기 때문에 많은 노력을 할 경우에 충분히 2006년 말에 완공될 수 있다고 생각하는데 사장은 어떻게 생각하십니까? 예, 가능하다고 생각합니다.   위원님께서도 잘 아시다시피 저희가 지금 적정규모 투자를 하다 보니까 집중투자를 할 수밖에 없습니다. 그래서 저희들이 준공시기에 맞춰서 항상 집중투자를 하다 보니까 한 2년 정도의 집중투자가 이루어지고 그 전에는 예산이 조금씩 들어가는 현상이 지금도 일어나고 있습니다.  이해를 해 주십시오. 그렇게 공사말기에 가서 집중투자를 해서 공사를 하다보면 공사 자체도 부실화될 수 있고 또 여러 가지 문제점이 발생할 수 있습니다.  빠른 개통을 위해서 최대한 노력을 해야 한다는 말씀도 드립니다.  다음은 행담도 개발과 관련해서 질의하겠습니다.  행담도 복합휴게단지는 본 위원의 지역구에 위치해 있기도 하고 특히 우리나라에서 최초로 개발되는 도로연접 복합휴게단지라는 점에서 본 위원이 관심 있게 지켜본 사업입니다.  이 사업 중 고속도로 휴게소를 설치하는 1단계 사업은 2000년도 말에 완료되었고 현재 많은 방문객이 이용하고 있을 뿐만 아니라 이 곳이 관광코스로도 많이 애용되고 있음을 잘 알고 있습니다.  그런데 문제는 2단계 사업 부분입니다.  섬 주변 공유수면을 매립하여 부지를 조성한 후 해양수족관 등 해양 리조트 시설을 건립하는 계획이 추진되고 있는 것으로 알고 있습니다만 2단계 사업은 환경영향평가 협의 및 매립 인ㆍ허가 추진 과정에서 매립면적이 당초 계획인 34만 7000㎡의 약 30% 정도에 해당하는 10만 1618㎡가 축소된, 24만 5382㎡로 결정되었고 그로 인해 부득이 사업계획 조정이 불가피할 수밖에 없을 것으로 보입니다.  즉 매립면적의 축소로 인해 이용 가능한 부지면적은 감소하게 되었고 그 때문에 당초 계획하였던 시설물에 대한 규모 등의 조정이 불가피 하게 되는 것은 당연한 결과라고 생각합니다.   그러나 환경영향평가 협의에서 지적된 사항들을 존중해서 충실히 따라야 한다고 생각합니다. 환경부를 비롯한 관련 기관이 제시한 의견은, 매립으로 인해 우려되는 각종 환경문제 발생을 최소화하자는 차원인 것으로 본 위원은 이해하고 있습니다.  그런데 한편으로는 이러한 상황 속에서도 민간사업자인 행담도개발주식회사 측에서는 사업비를 당초보다 증액시키고 투자비 대부분을 외자로 유치하기로 하면서 당초 1억 4000만 달러를 유치하려고 하였던 것을 4억 달러 유치로 변경시켰다고 하는데 이와 같은 외자유치는 매우 바람직한 현상으로 평가됩니다. 도로공사는 앞으로 보다 적극적으로 외자가 유치될 수 있도록 노력해야 한다고 생각합니다.  사장께 묻겠습니다.  매립면적 축소로 인해 야기되는 문제는 어떤 것이 있는지 밝혀 주시기 바라며 이에 대한 도공의 대책은 무엇인지도 말씀해 주시기 바랍니다.  또한 현재 계획 중인 외자유치가 원활하게 될 수 있도록 도로공사가 어떠한 지원을 할 계획인지 그리고 정부 차원에서는 어떠한 지원이 필요한 것인지도 밝혀 주시기 바랍니다.  다음은 하이패스 사업에 관해 질의하겠습니다.  하이패스 사업은 그 취지와는 정반대로 오히려 출퇴근길 지체를 가중시키는 주범이 되고 있다는 민원이 제기되고 있습니다.   그런데 더 큰 문제는 이 시범사업이 장비의 성능을 점검하고 문제를 해결하는 차원에 이르지를 못하고 단지 하나의 장식물의 진열에 그쳤다는 점입니다.  도로공사는 2000년 6월부터 무선수동방식 전자요금징수시스템을 경부선의 판교ㆍ청계ㆍ성남 톨게이트를 대상으로 단말기 1만 7000대를 보급하여 시범 운영을 시작했습니다.  그 뒤 시범 운영한 지 1년만인 2001년 6월 무선수동방식 단말기의 추가적인 판매를 중단하였고 시범 운영 2년만인 2002년 10월에 하이패스 사업 계획을 재수립하기에 이르렀습니다. 사업계획을 재수립하게 된 원인은 현재 운영 중인 하이패스 시스템을 2003년 6월까지 철거하도록 정보통신부가 요청한 데에서 비롯되었습니다.  이 때문에 하이패스 전용차로는 가뜩이나 교통수요가 높은 도로에서 무용지물이 되어 하나의 장식품으로 전락하면서 오히려 교통 혼잡만을 가중시켜 일반 차량들의 따가운 눈총을 받고 있습니다.  특히 현재 시범 운영되고 있는 무선수동단말기는 2004년 6월까지만 사용할 수 있고 그 이후 1만 7000여 대의 단말기를 모두 회수하여 폐기하여야 한다고 하는데 이로 인해 결과적으로 도로공사가 완전하지 못한 정책을 섣부르게 시행함으로써 국가적인 예산 낭비를 초래했다고 볼 수밖에 없습니다.  하이패스를 실시한 대상 톨게이트의 결정도 잘못된 것이었습니다.  성남ㆍ청계ㆍ판교 톨게이트를 대상으로 시범 운영되었는데 잘 아시는 것처럼 이 세 곳은 우리나라에서 고속도로별 평균 통행량이 가장 많은 경부선의 톨게이트입니다. 그런데 이곳에 보급된 단말기가 1만 7000대에 불과하였기 때문에 통행에 막대한 지 ...
# Answer: 예, 가능하다고 생각합니다.   위원님께서도 잘 아시다시피 저희가 지금 적정규모 투자를 하다 보니까 집중투자를 할 수밖에 없습니다. 그래서 저희들이 준공시기에 맞춰서 항상 집중투자를 하다 보니까 한 2년 정도의 집중투자가 이루어지고 그 전에는 예산이 조금씩 들어가는 현상이 지금도 일어나고 있습니다.  이해를 해 주십시오.
# Question: 그 답변 이전에 SOFA 관련해서 제가 물어 보았던 문제의 핵심은 미국 쪽에서도 물론 환경문제를 무시하는 것 같지는 않습니다.  그런데 환경문제를 SOFA의 본문에 별도의 환경조항으로 신설하려고 하지 않고 양해각서나 아니면 부속문서 그런 식으로 하는 것이 아닌가?  그런 여러 가지 관련된 이야기가 나오고 있기 때문에 제가 그 질의를 했는데 장관께서 그 부분에 대해서 명확하게 답변을 안 하시고 넘어가시는 것 같은데 미국 쪽의 입장이 어떻습니까?  환경을 SOFA 본문조항에 포함시키는 대신에 양해각서나 다른 부속문서를 통해 가지고 실질적인 환경보호 그런 부분들로 대체하자는 것 아닌가요?
# ...
# Answer: 그 부분에 대해서는 죄송한 말씀을 드리겠습니다.  설명을 조금 드리면 교정시설이 통합방위법에 의한 국가중요시설로서 국가보안목표로 지정되어 있어서 사진촬영이 통제되고 있습니다. 촬영이 사실은 불가능한 지역입니다. 그런데 현장에서 아마 촬영이 된 것 같아서 양해를 해 주셨으면 합니다. 여기서 하면 공개가 되기 때문에요.
# Question: 제가 말씀드리면 간척사업, 영농규모화사업, 농촌용수개발사업, 경지정리사업, 배수개선사업 같은 큰 사업들을 진행하고 있습니다. 그런데 독일이나 일본의 경우 60년대, 70년대에 이미 기반시설을 마쳤다고 하셨는데, 지금 우리나라는 이런 선진국에 비해 어느 정도 수준에 와 있습니까?
# Context: 먼저 질의 들어가기 전에 퇴직과 신규채용 자료의 통합 이후 직원 변동사항을 보면 2000년과 2003년 현재를 비교하면 임원과 1급ㆍ2급은 늘어났습니다. 특히 1급 같은 경우는 2000년 95개에서 현재는 120개로 늘어났습니다. 그러니까 임원부터 시작해서 2급까지는 늘어났고 대신 3급부터 6급까지는 줄어들었습니다. 어떻게 이런 일이 생겼는지 답변을 먼저 간단히 들어 보겠습니다.  우리가 볼 때는 줄면 같이 줄고 늘면 같이 늘어야지 밑은 줄고 위는 늘어나는 현상이 어떻게 생겼는지 설명해 주시겠습니까? 제가 이해를 못 해서 그렇습니다. 당초 통합 당시에 자리는 1급 T/O였습니다마는 통합 당시에 1급이 비어 있는 것을 직무대리로 운영하다가 1년 반 후에야, 통합된 후 초창기에 여러 가지로 어려움이 있기 때문에 승진을 안 시켰다가 나중에 승진시켰기 때문에 조금 늦었습니다. 그러면 2급은 왜 이렇게 늘어났습니까? 2급은 빠져 나갔기 때문에 늘어난 것입니까? 2급도 역시 처음에는 3개 기관을 통합했기 때문에 1년 반 동안은 승진인사를 일체 안 했습니다. 그래서 정년대기로 물러난 자리를 나중에 T/O대로 메우다 보니까 이렇게 늘어났습니다. 그러면 하위직은 왜 줄었습니까? 하위직이 줄어든 것은 통합 당시에 7700명이었습니다마는 현재 6372명으로 운영하고 있습니다. 그 이유는 그동안 정년으로 물러난 사람이라든지 명퇴라든지 기타 사유로 그만 두신 분들을 메우지 않고 꼭 필요한 기술직 인원만 몇 차례에 걸쳐서 채용했기 때문에 전반적으로 인원이 줄어들었습니다. 다만 그렇게 줄어들었음에도 불구하고 상위직 T/O는 채우다 보니까 상위직은 그대로 있고 하위직은 조금 많이 줄어들었습니다. 그런데 공교롭게 왜 농협하고 똑같은지 모르겠어요. 농협도 상위직은 늘어나고 하위직을 줄였습니다. 농업기반공사도 똑같은 현상이 일어나서 제가 궁금해서 물어 봤습니다. 그런데 만약에…… 이상 됐습니다.  제가 사장님 말씀을 믿기로 하고 새만금 문제와 관련해서 한 가지만 짚고 넘어가겠습니다. 앞으로 朱鎭旴 위원님께서 총괄적인 질의를 하시겠는데 이 문제가 여러 차례 논의되고 있지 않습니까?  지금 현상을 보면 본안소송까지 기다리는데 제가 반대하거나 찬성하는 문제가 아니라 許 장관은 들어오시자마자 다시 새만금을 해야 되고 다 하고 나면 농지로 해야 한다고 한 적이 있지요?  전라북도는 여기에 대해서 의견이 다릅니다. 전라북도는 일부는 신도시로 해야 된다는 등 의견이 다르고 아직 정부에서는 여기에 대한 입장을 정리하지 못하고 있고 환경단체나 이런 데서는 아직도 우려를 하고 있어서 승복을 못 하고 있는데 앞으로 농업기반공사는 어떻게 해야 된다고 생각합니까?  다시 한번 말씀드리면 어떻게 활용할지, 제가 여러 차례 이야기한 것입니다. 어떻게 활용하겠다는 대안을 내놓지도 못 하고 수질에 대한 확신도 못 주고 있고, 그리고 농림부장관은 농지로 해야 된다고 그러고 전라북도는 다른 이야기를 하고 있고, 그래서 제가 볼 때는 전라북도 도민들의 이익을 극대화할 필요도 있고 환경도 보전해야 되고…… 이것이 참 어려운 문제입니다.  옆에 공장단지가 있어서 공장단지로 할 수도 없고 이익은 극대화시켜야 되고 환경도 보전시켜야 되고 농지로도 할 수 없고, 어떻게 풀어야 될지 모르겠는데 이 문제가 계속 우리 국가의 가장 큰 현안이 되고 있지 않습니까? 이 문제를 어떻게 풀어야 됩니까? 위원님, 대단히 죄송스럽습니다마는 새만금사업에 대해서는 저희 농업기반공사가 국가 국책사업을 대행하는 입장이기 때문에 제가 감히 여기에서 왈가왈부하기에는 어렵습니다마는 공사는 계획대로 하되 토지 이용도에 대해서는 전반적으로 검토를 해서 거기에서 나온 결과대로 했으면 하는 것이 제 생각입니다. 지난번에 TV를 보니까 뒤에 계신 본부장님께서 ‘일단 땅을 확보하는 것이 저희 목적입니다’ 비슷하게 텔레비전에 나와서 말씀하시는 것을 들었습니다. 예, 그렇습니다. 저희들이 계속 동의를 못 하는 부분이, 해석을 한다면 일단 확보해 놓고 나중에 보자는 논리거든요? 꼭 그런 뜻은 아닙니다. 그러니까 이 부분에 대해서 이해를 못 하는 것이거든요. 지금 전라북도 도민들은 이 문제에 정서적으로 접근하고 있지 않습니까? 마치 이것이 안 되면 굉장히 무시를 하거나 아니면 자존심이 상하는 것으로 판단하고 계시고 정부는 여기에 대해서 어떤 방안을 내놓지도 못 하고 있고, 이런 고민이 있기 때문에 더 큰 문제라고 생각합니다.  농업기반공사는 전에는 이 문제에 대해서 홍보를 많이 하고 다니셨는데 지금은 ‘우리는 단순히 시행을 하는 업체일 뿐입니다’ 그렇게 극도로 몸을 낮추고 계십니다. 앞으로 이 문제는 朱鎭旴 위원께서 더 말씀을 하시리라고 생각합니다.   그러면 농업기반공사의 앞으로의 존재 이유에 대해서 같이 생각을 해 보고 싶습니다. 제가 농촌을 많이 다녀 봤습니다마는 농업기반공사는 용배수사업부터 시작해 여러 가지 일이 많은데 예산이 없지 않습니까? 그래서 현장에 가면 돈이 없어서 못 해 주는 경우가 굉장히 많습니다. 그래서 농민들이 농업기반공사를 찾아가면 예산이 없어서 못해 주겠다, 시청에 가서 알아보라고 하고 또 시청에 가면 그것은 농업기반공사 소관이라고 얘기합니다. 그래서 농민들은 양쪽을 그냥 왔다 갔다 하다가 저를 찾아옵니다. 제가 이것을 한두 번 경험하는 것이 아닙니다.   그래서 이런 경우가 앞으로도 계속될 텐데 이런 문제를 어떻게 풀어야 될지, 그리고 농업기반공사 사업을 보면 간척사업이 큰 부분을 차지하고 있습니다. 그렇지요, 사장님? 전체예산의 약 15% 정도를 간척이나 대단위사업이 차지하고 있습니다. 제가 말씀드리면 간척사업, 영농규모화사업, 농촌용수개발사업, 경지정리사업, 배수개선사업 같은 큰 사업들을 진행하고 있습니다. 그런데 독일이나 일본의 경우 60년대, 70년대에 이미 기반시설을 마쳤다고 하셨는데, 지금 우리나라는 이런 선진국에 비해 어느 정도 수준에 와 있습니까? 독일 같은 경우는 40년대에 다 끝난 상태이고 우리 같은 경우는 지금까지 정부에서 막대한 돈을 들였습니다마는―그리고 오전에도 보고를 드렸습니다마는―10년 빈도에 견딜 수 있는 수리안전답은 전체 38% 수준밖에 안 되기 때문에 저희들 입장에서는 앞으로도 지속적으로 사업을 해야 된다고 생각합니다. 독일 같은 경우는 이미 40년대에 끝났고 일본 같은 경우도 60년대, 70년대에 끝났습니다. 그런데 우리는 金泳三 정부 때부터 구조개선사업을 하면서 많은 성과를 거둔 것도 사실입니다. 그래서 쌀 증산도 상당히 이루어졌습니다.   그런데 앞으로 2010년이 넘으면 신규 간척사업은 저항도 크고 환경문제도 계속해서 따르기 때문에 거의 불가능할 것으로 보입니다. 그리고 영농규모화사업도 2010년까지 약 7만 호를 하겠다고 하셨는데 이런 것들이 우리나라 농업의 전환기라고 보는 2010년 내에는 상당 부분 진척될 것으로 봅니다. 그리고 농업기반공사는 5000명 되는 굉장히 큰 기업입니다. 그런데 앞으로 농업기반공사의 역할을 어떻게 해 갈 것인지, 단순히 물관리 하나만 하실 것인지? 제가 볼 때 좀 걱정이 돼서 드리는 말씀입니다.   그리고 앞으로는 모든 업무가 지방단위로 계속 이관될 것입니다. 농림부 업무뿐만 아니라 상당수가 지방자치단체로 이양될 텐데 지금 농업기반공사에 대한 농민들의 불신은 더 커지고 있습니다. 물론 저는 이렇게 된 것이 공사의 책임이라고는 보지 않습니다. 옛날보다 어려운 상황에서, 예산도 없는 상태에서 적은 인원으로 하다 보니까 농민들의 불만은 커지고 사업은 계속 위축될 수밖에 없는 상황인데 농업기반공사는 앞으로 어떻게 존재 이유를 찾아갈 것인지 하는 것이 걱정됩니다.   거기에 대해 나중에 말씀을 좀 해 주시고요, 그리고 보고서를 보면 쌀 전업농 육성정책이 농업기반공사가 가장 자랑스럽게 생각하는 업무 중의 하나인 것 같습니다. 그런데 정부가 94년부터 쌀 전업농 육성정책을 실시하면서 여러 번 바꾸었습니다. 94년도에는 95년부터 쌀 전업농 육성사업 시행한다, 10만 호 육성한다, 96년에는 쌀산업종합대책을 내놓으면서 여러 가지 대책을 내놓았습니다. 98년에는 가족농 중심의 농업구조 정책을 실시하겠다, 2002년에는 쌀산업종합대책이라고 해서 내놓 ...
# Answer: 독일 같은 경우는 40년대에 다 끝난 상태이고 우리 같은 경우는 지금까지 정부에서 막대한 돈을 들였습니다마는―그리고 오전에도 보고를 드렸습니다마는―10년 빈도에 견딜 수 있는 수리안전답은 전체 38% 수준밖에 안 되기 때문에 저희들 입장에서는 앞으로도 지속적으로 사업을 해야 된다고 생각합니다.
# Question: 그러면 실화재시험장에서 터널, 공동구와 관련된 실험을 다 할 수 있습니까?
# Context: 한국소방검정공사 權 사장님, 답변 잘 들었는데 부임하신 지 1주일 밖에 안 되셨지요? 한 달 되었습니다. 아까 답변에 실화재시험장이 금년 7월에 설립되었다는 말씀을 하셨는데 權 사장님, 내용은 훤하게 알고 계십니까? 알면 답변하셔도 되고 모르시다면 담당 이사님이 답변해도 되니까 아주 간단하게 묻겠습니다.   장소는 어디에 했습니까? 공사 내에 같이 있습니다. 규모는 어느 정도 돼요? 바닥면적이 450평, 실내높이는 18m입니다. 재원은 어떻게 마련된 것입니까? 재원은 신청사를 지으면서 일부 30억이 모자라는 것 같아서 은행에서 기채하기로 하고 신청사 지을 때 같이 한꺼번에 추진했습니다. 그러면 실화재시험장에서 터널, 공동구와 관련된 실험을 다 할 수 있습니까? 근래에 국내나 외국에도 터널에 화재가 종종 납니다. 연구기관 구축이 절실해서 이왕 짓는 김에 터널도 구축하고 지하공동구도 통신망, 신경망이 마비되니까 여기에 대한 연구기관 구축이 필요합니다. 알겠습니다. 잘 하셨고요.   실화재시험장과 관련된 현황을 자료로 주세요. 예, 알겠습니다. 이상입니다.
# Answer: 근래에 국내나 외국에도 터널에 화재가 종종 납니다. 연구기관 구축이 절실해서 이왕 짓는 김에 터널도 구축하고 지하공동구도 통신망, 신경망이 마비되니까 여기에 대한 연구기관 구축이 필요합니다.
# Question: 저도 그렇게 생각하는데 여론이 그렇다는 얘기입니다.  지금 문제가 무엇인가 하니 우리나라는 지금 20년 전후 된 아파트를 헐어 가지고 재건축을 하고 있지요? 그런데 한심한 게, 자꾸 외국의 예를 들어서 죄송합니다마는, 미국은 평균 수명이 103년입니다. 영국은 141년, 독일은 79년, 일본의 30년에 비하면 우리나라가 20년을 전후해서 재건축한다는 것은 자원낭비가 아니겠느냐 생각하는데 사장님 여기에 대해서 어떻게 생각하십니까?
# Context: 자유민주연합의 宋光浩 위원입니다.  권해옥 사장님을 비롯한 임직원 여러분, 우리 국민들의 주거환경을 보다 더 낫게 하고 삶의 질을 높이기 위해 항상 고생하시는 데 대하여 진심으로 위로와 존경의 말씀을 드립니다. 질의에 앞서 한 가지만 물어보겠습니다.  현재 주택공사의 임직원이 2978명인데 장애인 직원을 보니까 1급 1명, 2급 1명, 3급 6명, 4급 15명으로 총 23명입니다. 그런데 대개 2%를 고용하도록 되어 있으니까 한 60명∼70명은 고용을 해야 2%가 되지 않느냐, 23명은 대단히 낮은 수준이라고 생각합니다.  제가 가는 곳마다 장애인들에 대한 취업현황을 받아봤는데 거의 2.3%, 2.5%입니다. 그런데 유독 주택공사만 이렇게 낮습니다. 그래서 사장님께 여기에 대한 관심을 좀 가져 주십사 하는 부탁을 드립니다.  우리가 언제 장애인이 될지 모르고 나의 직계가족이 언제 장애인이 될지 모릅니다. 그들과 우리가 함께 살아가는 사회를 만드는 데도 관심을 가져 주십사 하는 말씀을 드립니다.  그리고 여성직원이 416명 있는데 최고위직이 책임연구원, 책임연구원도 임직원에 속합니까? 예, 그렇습니다. 174명 중에 2급이 3명 있습니다. 여직원을 채용한 시기가 늦어서 그런지 임원 7명 중에 1명도 없고 1급 38명 중에도 1명 없고 2급 174명 중에만 고작 3명입니다. 그리고 3급은 675명 중에 4명입니다. 이런 부분에 있어서도 여성들이 사회에 적극적으로 참여할 수 있도록 제도적인 바탕이 있어야 할 것입니다. 여기에 대해서 사장님은 어떻게 생각하십니까? 사실 宋光浩 위원님께서 지적하신 말씀은 지당합니다. 그런데 주택공사는 주로 현장근무를 해야 되는데 여직원이 할 일이 많지 않기 때문에 여직원 배정 숫자가 적은 것 같이 보여집니다마는 앞으로 적절히 배치될 수 있도록 유념하겠습니다. 제가 금년에 건설현장을 다니다 보니까 어느 건설회사에서는 여성 소장을 쓰고 있던데 일을 더 섬세하게 잘 한다고 그러더라고요. 특히 주택의 경우에는 사소한 손길이 여러 번 가야 되는 것이기 때문에 여자를 현장 소장으로 내보내면 남자 소장보다 더 잘 할 수 있으리라 생각합니다. 그러니까 관심을 좀 가져 주십사 하는 부탁을 드립니다.  제가 이번에 현장을 다니면서 보니까 어느 현장이든 사소한 지적이 없을 수는 없습니다. 그런데 저는 주거환경이 제대로 만들어져 있느냐, 설계를 제대로 했느냐, 옛날 와우아파트처럼 무너질 수 있는 그런 부실공사가 아닌가 하는 것을 중점적으로 봤습니다.  제가 청주하고 부산의 턴키공사 현장을 다녀봤는데 일반주택보다 턴키로 해서 하는 것이 주거공간이 더 넓더라고요. 그리고 정원을 잘 만들어 가지고 주민들이 문화활동할 수 있는 그런 공간도 잘 되어 있고 해서 새로운 제도를 도입한 주택공사 임직원들에게 잘 했다는 칭찬의 말씀을 드립니다.  다음은 국민주택기금에 대해서 묻겠습니다.   국민주택기금은 20년 전 서민주택 건설을 촉진하기 위해 만들었는데 이것이 어떻게 된 일인지 2000년 말 통계에 의하면 국민주택기금을 가지고 집을 짓다 부도가 발생한 사업장이 786개, 호수로 말하면 22만여 호입니다. 그렇게 작은 규모인데도 한 3조 원을 넘고 있습니다. 그런데 이 말을 왜 이렇게 하느냐, 지금 주택은행이 민영화된 것 사장님 알고 계시지요? 예, 알고 있습니다. 주택기금을 주택공사에서 관리하는 방법은 없겠느냐, 내가 비전문가라서 깊이 연구를 안 해보고 묻는 겁니다. 여기에 대한 사장님의 견해도 말씀해 주시기 바랍니다.  제가 중요한 요점만 말씀드리고 상세한 것은 서면으로 질의드리고 서면으로 답변을 받도록 하겠습니다.  지금 임대주택이 서울에는 모자라지요? 많이 모자랍니다. 시골에는 그런 대로 되는데, 남는 데도 있습니까? 시골에도 임대주택은 남는 데가 없습니다. 서울에 과연 지을 땅이 있습니까? 그래서 지금 현재 건교부하고 정부에서 그린벨트를 해제해서 지으려고 애를 쓰고 있는 것으로 알고 있습니다. 그래서 우선 건교부하고 상의해 가지고 그린벨트가 해제되는 곳에 주택지를 빨리 확보해야 되겠다는 말씀을 제가 드립니다.  그런데 선진국에 비하면 우리나라는 일반주택보다 임대주택 비율이 굉장히 낮습니다. 네덜란드가 36%, 영국이 24%, 스웨덴이 22%, 프랑스 17%에 비하면 우리나라는 영구임대주택과 50년 공공임대주택이 겨우 2.3%에 불과합니다.  그러니까 제가 주공하고 토공의 통폐합을 반대하는 이유도 여기 있는 겁니다. 이런 서민들이 살 수 있는 주거환경을 만드는데 노력해 주십사 하는 말씀을 드립니다.  지금 도시정비사업을 하고 있지요? 재개발 재건축…… 주택공사도 수익사업을 하지 않느냐 이런 얘기가 있는데 사장님은 어떻게 생각하십니까? 사실 수익사업을 하는 것보다는 저희들이 달동네 문제를 해결하기 위한 도시정비차원에서 하고 있습니다. 돈도 지자체에서 많이 부담하게 됩니다.   그래서 실제로 저희들이 이윤을 추구하는 공사가 아니기 때문에 돈을 벌려고 하는 것은 아니라는 것을 이해해 주시기 바랍니다. 저도 그렇게 생각하는데 여론이 그렇다는 얘기입니다.  지금 문제가 무엇인가 하니 우리나라는 지금 20년 전후 된 아파트를 헐어 가지고 재건축을 하고 있지요? 그런데 한심한 게, 자꾸 외국의 예를 들어서 죄송합니다마는, 미국은 평균 수명이 103년입니다. 영국은 141년, 독일은 79년, 일본의 30년에 비하면 우리나라가 20년을 전후해서 재건축한다는 것은 자원낭비가 아니겠느냐 생각하는데 사장님 여기에 대해서 어떻게 생각하십니까? 저도 宋 위원님과 같은 의견을 가지고 있습니다. 사실 우리나라에서는 건축할 때 너무나 졸속하게 한 것도 있고 도시화 계획을 제대로 수립하지 않았기 때문에 이런 재건축 상황이 일어나는 것 같이 보입니다. 이것은 앞으로 좀더 연구를 하면서 재건축 해야 된다고 생각합니다. 최소한도 주공에서 짓는 것은 20년 내에 헐고 다시 짓는다는 얘기가 나와서는 안 되겠지요? 저희들은 그렇게 하지 않습니다. 임원들은 어떻게 생각하세요? 거기에 대해서 각별한 관심을 가져주십사 하는 말씀을 드립니다.  제가 주공하고 통합을 반대하는 이유가 합했을 경우 부채가 21조 원이 넘습니다. 1년에 이자부담만 해도 1조 5000억, 하루 이자만 39억 원이라는 얘기예요. 그러니까 통합하다 보면 공룡 같은 부실 국영기업이 됩니다.   왜 그러느냐, 집을 짓는다는 얘기는 손이 여러 번 가고 또 공익을 위해서 하기 때문에 돈을 버는 것이 아니다 어떻게 보면 양질의 주택을 원가서비스해 주는 것인데 토공은 그래도 어찌 되었든간에 일 하기가 수월하고 또 일을 한 것만큼 차액이 주택보다는 많아요. 그러면 적은 노력으로 많은 소득을 올릴 수 있는 곳에 신경을 쓰고 서민들 주거환경을 개선하는 곳에는 자연적 신경을 덜 쓰게 되어 있다, 이것은 누가 사장이든지 사장이 나빠서가 아니고 누가 하더라도 사람이 심리적ㆍ본질적으로 그렇게 하게 되어 있어요.  그렇기 때문에 주택공사하고 토지공사가 통폐합하게 되면 우리나라 서민주택을 활성화하고 또 돈 없는 사람의 삶의 질을 높이는 공간을 만드는 일은 요원하다 그래서 저는 반대합니다. 여기에 대한 답변은 주택공사 사장님이 국영기업체 사장님이니까 원하지 않습니다. 내 생각이 그렇다는 것입니다.  그리고 또 한 가지 뉴하우징을 민영화하는 것이 사장님 방침입니까, 기획예산처 방침입니까? 정부 측 방침인데 저는 뉴하우징 문제에 있어 민영화하는 것을 반대합니다. 앞에서 존경하는 李在昌 위원님께서 말씀하셨는데 뉴하우징이 관리하는 것이 임대아파트가 많지요? 영구임대주택, 공공임대주택, 순수하게 아주 어려운 서민주택을 관리하기 때문에 다른 민영업체가 관리하게 되면 앞으로 엄청난 문제점이 도출되고 정말 도저히 해결할 수 없는 민원문제가 생길 겁니다. 하여튼 뉴하우징이 민영화되었을 경우 관리가 안 되는 거지요? 여러 가지가 죽 있는데 여기에 대한 질의를 생략하고 사장님의 의지가 그렇다니까 정확한 답변을 해 주시기 바랍니다.  이상입니다.
# Answer: 저도 宋 위원님과 같은 의견을 가지고 있습니다. 사실 우리나라에서는 건축할 때 너무나 졸속하게 한 것도 있고 도시화 계획을 제대로 수립하지 않았기 때문에 이런 재건축 상황이 일어나는 것 같이 보입니다. 이것은 앞으로 좀더 연구를 하면서 재건축 해야 된다고 생각합니다.
# Question: 그러면 제가 질의를 마치고요.  아까 유인물에서 질의를 했습니다마는 북한의 훈련수준이 해군이나 육군의 지상군에 비해서 떨어지는 이유를 공군에서는 어떻게 분석하고 있습니까?
# Context: 작년에 강릉에서 폭우피해로 인해 기지의 일부가 비에 쓸려 나간 처참한 모습을 보았는데 그것 다 복구되었습니까? 예, 다 복구되었습니다. 그런데 금년도에는 매미가 왔을 때 사전에 그것을 포착을 해서 사전대비를 철저히 했다고 하는데 비행기도 이전시키고 그런 사전대비를 했는지 모르겠네요? 강릉에 있는 비행기 중에 18대를 원주비행장으로 이틀 전에 이전을 시켜서 침수피해는 없었습니다. 어쨌든 작년도를 경험으로 해서 사전대비를 철저히 해야 될 것으로 압니다. 그리고 이번에 영공을 지키다가 순직한 순직자에게 여러 위원님들께서 조의를 표했습니다마는 저도 역시 조의를 표하면서 유가족에게 위로를 드립니다.  그리고 총장이 부임해서 선진 정예 공군 육성을 위해서 여러 가지 노력을 하고 있는 모습을 보고 있습니다. 오늘 질의할 것은 다섯 가지를 준비했는데 대부분 서면으로 질의를 하고 몇 가지만 내용을 소개하면 금년도 국방부요구예산안에 정밀타격체계 확립을 위한 공중급유기사업과 차기유도무기사업이 국가재정 부족이라는 이유로 기획예산처에서 다시 순연되었다는데 맞습니까? 예. 정말 자주국방을 구현하기 위해서는 대북억제전력과 대미의존전력을 우선적으로 확보하고 한반도 주변국에 대한 조기경보능력과 감시영역을 확장하며 전략표적에 대한 정밀타격능력 등 독자적인 전투수행능력 확보가 필요할 것으로 보는데 이와 같은 것이 공군의 전략형 공군력 건설에 미치는 영향이 크다고 보는데요? 영향이 큽니다. 전반적으로 사업이 연기되었기 때문에 전력증강 목표도 연기될 수밖에 없습니다. 그래서 자주국방의 목표연도도 좀 뒤로 연기되어야 하지 않겠는가 판단을 하고 있습니다. 그리고 한반도 주변국들은 이미 공중조기경보통제기를 활용해서 원거리작전 수행능력을 보유하고 있고 또 E-X사업은 공중급유기사업과 더불어서 반드시 추진해야 될 공군의 핵심 전력증강사업이 아닌가 생각합니다.    일본은 17대, 러시아는 16대, 대만과 중국도 각각 4대의 조기경보통제기를 보유하고 있는 실정인데 우리는 내년부터 추진한다 하더라도 여기 보고서에 나와 있는 것처럼 2009～2011년에 가서야 총 4대를 확보하게 되는 것이지요? 그렇습니다. 이것도 98년도에 사업 착수를 하려고 했지만 IMF 사태와 그 이후에 GDP 대비 2.7%라는 제한적인 국방예산 배정 때문에 계속 순연되어 왔는데 더 이상 연기되어서는 안 될 것으로 보는데 보고하신 대로 그대로 진행될 것이라고 생각하십니까? 연기되어서는 안 될 중요한 사업입니다. 그런데 가용예산규모가 자꾸 축소되고 있기 때문에 공군에서도 걱정을 많이 하고 있습니다. 지금 여기 보고서에는 계획대로 추진을 한다고 되어 있는데요? E-X 사업은 최우선 순위를 두고 추진하는 사업입니다.  그래서 다른 사업이 좀 지연되더라도 E-X 사업을 우선적으로 추진하려고 하고 있습니다. 본 위원도 국회 국방위원회의 방위력개선소위원회 위원장을 맡고 있기 때문에 관심을 가지고 국회 차원에서 지원을 할 수 있도록 그렇게 노력하겠습니다.    다음 세 번째는 급변하는 한반도 안보환경하에서 우리 공군이 향후 10년 내지 20년 후의 미래전장환경을 염두에 두고 대한민국의 국익보호를 위한 항공작전계획을 수립해야 될 것으로 압니다. 그런데 지금 활주로를 신설하거나 또 기존활주로(정석 비행장)가 있지요? 제주도에 있습니다. KAL 보유 비행장입니다. 그 기반시설이 바로 제주도 전략기지 확보라고 보는데 그것을 활용하는 방안에 대해서 총장의 견해를 말씀해 주시기 바랍니다. 서면으로 보고드리겠습니다. 알겠습니다.    다음 공군의 연간 비행훈련시간 문제입니다.    매년 국감 때마다 나오는 얘기입니다마는 연간 180시간 정도가 목표이지요? 예, 지금은 160시간 정도로 목표를 하향조정했습니다. 그런데 지난 김대중 정부가 들어선 이후부터 국가경제여건의 악화로 GDP 대비 2.7% 수준으로 국방예산이 하락한 이후에 연간 140시간 이하로 감소되어 운영되는 것으로 알고 있는데 공군전투력의 질적 저하가 우려되는 상황이 아닌가 생각됩니다. 2000년도 138시간, 2001년도 135시간, 2002년도는 130시간 40분으로 알고 있습니다. 훈련시간이 일본은 평균 200시간, 대만은 180시간, 미국 220시간입니다.   북한 핵을 비롯한 안보위기에 직면하고 있는 우리나라의 경우 140시간에도 미치지 못하고 있는데 북한은 지금 얼마입니까? 북한은 1인당 10시간 정도로 파악이 되고 있습니다. 10시간요? 조종사수가 3500명이나 되어서 많기 때문에 훈련량을 전체로 나누다 보니까 그렇게 된 것 같고 실제로 작전부대에 있는 조종사들의 비행훈련시간은 그보다 많을 것으로 판단하고 있습니다. 그래서 본 위원이 판단할 때는 적정목표 비행시간이라고 하는 연간 180시간, 아니면 최소 160시간은 유지되어야 할 것으로 생각이 되는데 거기에 대해서는 총장도 노력하겠습니다마는 이따가 답변을 통해서 견해를 말씀해 주시기 바랍니다. 알겠습니다. 마지막으로 우수 공군조종사의 조기전역 방지를 위한 대책방안에 대해서 질의를 하려고 했는데 보고서 39페이지에 “전투기 조종사 조기전역 방지” 내용이 나와 있기 때문에 서면질의로 하겠습니다.    그런데 일반적으로 공군조종사들이 조기전역하려고 하는 것이 진급 공석의 부족에 따른 진급제한, 두 번째는 과중한 업무부담, 세 번째는 민간 항공사와의 보수격차―민항대비해서 한 71%로 밖에 안 된다고 하는데―이 세 가지 중에 주 원인이 무엇입니까? 진급에 대한 불확실성 때문입니다. 그래서 내년도부터 사관학교 모집인원을 150～160명으로 대폭 줄여서 모집을 할까 합니다. 국방부의 허락을 받았습니다. 그러면 제가 질의를 마치고요.  아까 유인물에서 질의를 했습니다마는 북한의 훈련수준이 해군이나 육군의 지상군에 비해서 떨어지는 이유를 공군에서는 어떻게 분석하고 있습니까? 8월 30일까지 저희들이 파악한 자료에서 북한은 약 1만 6700소티를 비행했습니다. 그래서 북한의 훈련량은 과거 3년의 평균치와 비교할 때 대등한 수준입니다. 작년치보다 조금 적은 수준이기는 합니다마는 과거 3년치와 평균적으로 비교할 때 대등한 수준입니다. 북한 공군의 훈련량은 변함이 없다고 저희들은 판단하고 있습니다. T-50고등훈련기에 대해서 張永達 위원장님과 국방위원회 유럽지역 시찰단에서는 ‘우리도 방산 수출 좀 해 보자’ 그래서 의원외교활동을 통해 고등훈련기를 수출하기 위해서 각 나라의 국방위원장들을 만날 때마다 ‘당신네 나라에서 T-50고등훈련기를 사 주면 우리도 거기에 관계되는 헬리콥터나 이런 기술을 도입하고 필요한 장비를 도입할 수 있지 않겠느냐, 우리의 방산 수출이 너무 역조현상이 나니까 이것을 시정하기 위해서도 우리 항공기를 사 달라’ 이렇게 이야기했습니다. 그랬더니 저희들이 만났던 영국의 국방위원장이나 거기 방산업체 관계자들도 T-50고등훈련기에 대해서는 굉장히 높게 평가하는데 ‘거기에 대해서 어떻게 알고 있느냐’ 하니까…… T-50이 언제 에어쇼에 참가했습니까? 파리 에어쇼에 그 모형이 참가했습니다. 그래서 이것이 유럽에 잘 알려져 있어요.  그렇기 때문에 이것은 상당히 가능성이 있지 않느냐 하는 것을 우리가 느끼고 왔는데 총장으로서는 어떻게 생각하십니까? T-50을 만들면서 앞으로 한 800대까지는 수출할 수 있지 않겠나 하는 것이 업자 측의 판단입니다. 그런데 그와 가장 경쟁되는 것이 영국에서 만들고 있는 호크(Hawk)기입니다. 그래서 영국에서 T-50에 대해 각별히 관심을 갖고 있지 않나 이렇게 판단이 됩니다.   록히드마틴사에서는 앞으로 고등훈련기의 세계적 소요가 3300대인데 그 중에 한 800대 정도는 T-50으로 수출이 가능하지 않겠느냐 이렇게 판단하고 있습니다. KT-1은 어떻게 생각하고 있습니까? 지금 멕시코, 에콰도르, 싱가포르와 수출협상을 추진 중에 있다고 되어 있는데요. KT-1은 지난 9월 10일까지 인도네시아에 이미 7대를 수출했습니다. 그래서 조종사, 정비사들이 저희 공군에 와서 훈련을 받고 갔습니다. 인도네시아에 수출한 7대에 대해서는 저희 공군에서 시험비행까지 해 주었습니다. 그래서 저희 공군에서 적극 지원을 하고 있는데 KAI에서 KT-1 수출을 위해서 여러 나라를 방문하고 있는 ...
# Answer: 8월 30일까지 저희들이 파악한 자료에서 북한은 약 1만 6700소티를 비행했습니다. 그래서 북한의 훈련량은 과거 3년의 평균치와 비교할 때 대등한 수준입니다. 작년치보다 조금 적은 수준이기는 합니다마는 과거 3년치와 평균적으로 비교할 때 대등한 수준입니다. 북한 공군의 훈련량은 변함이 없다고 저희들은 판단하고 있습니다.
